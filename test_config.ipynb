# %%
from utils.config import Config

Config.load()
print("Biomass Model Parameters:")
print("  m:", Config.m)
print("  n:", Config.n)

print("\nGrowth Model Parameters:")
print("  b:", Config.b)
print("  a:", Config.a)
print("  h:", Config.h)
print("  k_min:", Config.k_min)
print("  j:", Config.j)
print("  T_opt:", Config.T_opt)
print("  T_min:", Config.T_min)
print("  T_max:", Config.T_max)
print("  UIA_crit:", Config.UIA_crit)
print("  UIA_max:", Config.UIA_max)
print("  DO_crit:", Config.DO_crit)
print("  DO_min:", Config.DO_min)
print("  kappa:", Config.kappa)


print("\nLatitude by Region:")
print("  guangdong:", Config.ind_growth_model.latitude.guangdong)
print("  north_sulawesi:", Config.ind_growth_model.latitude.north_sulawesi)
print("  kafr_el_sheikh:", Config.ind_growth_model.latitude.kafr_el_sheikh)

print("\nTemperature Model by Region:")
print("  guangdong:")
print("    T_mean:", Config.temp_model.guangdong.T_mean)
print("    T_amp:", Config.temp_model.guangdong.T_amp)
print("    phase_shift:", Config.temp_model.guangdong.phase_shift)

print("  north_sulawesi:")
print("    T_mean:", Config.temp_model.north_sulawesi.T_mean)
print("    T_amp:", Config.temp_model.north_sulawesi.T_amp)
print("    phase_shift:", Config.temp_model.north_sulawesi.phase_shift)

print("  kafr_el_sheikh:")
print("    T_mean:", Config.temp_model.kafr_el_sheikh.T_mean)
print("    T_amp:", Config.temp_model.kafr_el_sheikh.T_amp)
print("    phase_shift:", Config.temp_model.kafr_el_sheikh.phase_shift)

print("\nReward Cost Parameters by Region:")
print("  guangdong:")
print("    P_s:", Config.reward_cost_parameters.guangdong.P_s)
print("    P_f:", Config.reward_cost_parameters.guangdong.P_f)
print("    P_e:", Config.reward_cost_parameters.guangdong.P_e)

print("  north_sulawesi:")
print("    P_s:", Config.reward_cost_parameters.north_sulawesi.P_s)
print("    P_f:", Config.reward_cost_parameters.north_sulawesi.P_f)
print("    P_e:", Config.reward_cost_parameters.north_sulawesi.P_e)

print("  kafr_el_sheikh:")
print("    P_s:", Config.reward_cost_parameters.kafr_el_sheikh.P_s)
print("    P_f:", Config.reward_cost_parameters.kafr_el_sheikh.P_f)
print("    P_e:", Config.reward_cost_parameters.kafr_el_sheikh.P_e)

print("\nCommon Reward Cost Parameters:")
print("  c_p:", Config.reward_cost_parameters.common.c_p)
print("  V:", Config.reward_cost_parameters.common.V)
print("  m:", Config.reward_cost_parameters.common.m)
print("  P_max:", Config.reward_cost_parameters.common.P_max)
# Out:
# Biomass Model Parameters:
#   m: 0.67
#   n: 0.81
#
# Growth Model Parameters:
#   b: 0.62
#   a: 0.53
#   h: 0.8
#   k_min: 0.00133
#   j: 0.0132
#   T_opt: 33
#   T_min: 24
#   T_max: 40
#   UIA_crit: 0.06
#   UIA_max: 1.4
#   DO_crit: 1.0
#   DO_min: 0.3
#   kappa: 4.6
#
# Latitude by Region:
#   guangdong: 23.5
#   north_sulawesi: 1.5
#   kafr_el_sheikh: 31.1
#
# Temperature Model by Region:
#   guangdong:
#     T_mean: 22.5
#     T_amp: 7.5
#     phase_shift: 80
#   north_sulawesi:
#     T_mean: 23.0
#     T_amp: 9.0
#     phase_shift: 70
#   kafr_el_sheikh:
#     T_mean: 27.0
#     T_amp: 2.0
#     phase_shift: 90
#
# Reward Cost Parameters by Region:
#   guangdong:
#     P_s: 1.34
#     P_f: 1.12
#     P_e: 0.088
#   north_sulawesi:
#     P_s: 2.07
#     P_f: 1.29
#     P_e: 0.0068
#   kafr_el_sheikh:
#     P_s: 2.53
#     P_f: 0.55
#     P_e: 0.047
#
# Common Reward Cost Parameters:
#   c_p: 4.2
#   V: 2000
#   m: 1
#   P_max: 0.102
