# %%
hyperparams = [
    # 01: Fast learning, strong future emphasis, slow target smoothing, automatic entropy tuning
    {"learning_rate": 1e-3, "gamma": 0.99, "tau": 0.005, "ent_coef": 'auto'},

    # 02: Same as #1 but with fixed entropy coefficient (less stochasticity)
    {"learning_rate": 1e-3, "gamma": 0.99, "tau": 0.005, "ent_coef": 0.1},

    # 03: Faster target smoothing (τ=0.01), moderate entropy for balanced exploration
    {"learning_rate": 1e-3, "gamma": 0.99, "tau": 0.01,  "ent_coef": 0.05},

    # 04: Lower future emphasis (γ=0.98), slow τ, high entropy for more exploration
    {"learning_rate": 1e-3, "gamma": 0.98, "tau": 0.005, "ent_coef": 0.2},

    # 05: Lower γ, faster τ, low entropy coefficient for stable training
    {"learning_rate": 1e-3, "gamma": 0.98, "tau": 0.01,  "ent_coef": 0.01},

    # 06: Lower γ, faster τ, auto entropy with small target entropy (more exploration)
    {"learning_rate": 1e-3, "gamma": 0.98, "tau": 0.01,  "ent_coef": 'auto_0.1'},

    # 07: Half learning rate, high γ, slow τ, high entropy for exploration
    {"learning_rate": 5e-4, "gamma": 0.99, "tau": 0.005, "ent_coef": 0.2},

    # 08: Half LR, high γ, faster τ, moderate entropy
    {"learning_rate": 5e-4, "gamma": 0.99, "tau": 0.01,  "ent_coef": 0.05},

    # 09: Half LR, lower γ, slow τ, auto entropy tuning
    {"learning_rate": 5e-4, "gamma": 0.98, "tau": 0.005, "ent_coef": 'auto'},

    # 10: Half LR, γ=0.98, slow τ, low entropy for conservative policy
    {"learning_rate": 5e-4, "gamma": 0.98, "tau": 0.005, "ent_coef": 0.01},

    # 11: Half LR, γ=0.98, faster τ, moderate entropy
    {"learning_rate": 5e-4, "gamma": 0.98, "tau": 0.01,  "ent_coef": 0.05},

    # 12: Half LR, γ=0.98, faster τ, high entropy for max exploration
    {"learning_rate": 5e-4, "gamma": 0.98, "tau": 0.01,  "ent_coef": 0.2},
]

print(f"Total configs: {len(hyperparams)}\n")
for i, config in enumerate(hyperparams, 1):
    print(f"[Hyperparameter {i:03}] {config}")
# Out:
# Total configs: 12
#
# [Hyperparameter 001] {'learning_rate': 0.001, 'gamma': 0.99, 'tau': 0.005, 'ent_coef': 'auto'}
# [Hyperparameter 002] {'learning_rate': 0.001, 'gamma': 0.99, 'tau': 0.005, 'ent_coef': 0.1}
# [Hyperparameter 003] {'learning_rate': 0.001, 'gamma': 0.99, 'tau': 0.01, 'ent_coef': 0.05}
# [Hyperparameter 004] {'learning_rate': 0.001, 'gamma': 0.98, 'tau': 0.005, 'ent_coef': 0.2}
# [Hyperparameter 005] {'learning_rate': 0.001, 'gamma': 0.98, 'tau': 0.01, 'ent_coef': 0.01}
# [Hyperparameter 006] {'learning_rate': 0.001, 'gamma': 0.98, 'tau': 0.01, 'ent_coef': 'auto_0.1'}
# [Hyperparameter 007] {'learning_rate': 0.0005, 'gamma': 0.99, 'tau': 0.005, 'ent_coef': 0.2}
# [Hyperparameter 008] {'learning_rate': 0.0005, 'gamma': 0.99, 'tau': 0.01, 'ent_coef': 0.05}
# [Hyperparameter 009] {'learning_rate': 0.0005, 'gamma': 0.98, 'tau': 0.005, 'ent_coef': 'auto'}
# [Hyperparameter 010] {'learning_rate': 0.0005, 'gamma': 0.98, 'tau': 0.005, 'ent_coef': 0.01}
# [Hyperparameter 011] {'learning_rate': 0.0005, 'gamma': 0.98, 'tau': 0.01, 'ent_coef': 0.05}
# [Hyperparameter 012] {'learning_rate': 0.0005, 'gamma': 0.98, 'tau': 0.01, 'ent_coef': 0.2}

# %%
import matplotlib.pyplot as plt

from envs.aquaculture_env import AquacultureEnv
from stable_baselines3 import SAC
import torch

EPISODES = 100
TIMESTEPS = 180 * EPISODES
region = "north_sulawesi"
all_rewards = []

for idx, hp in enumerate(hyperparams, 1):
    print(f"Training config #{idx}...")
    env = AquacultureEnv(region=region)
    model = SAC(
        "MlpPolicy",
        env,
        verbose=0,
        learning_rate=hp["learning_rate"],
        gamma=hp["gamma"],
        tau=hp["tau"],
        ent_coef=hp["ent_coef"],
        batch_size=256,
        device="cuda" if torch.cuda.is_available() else "cpu"
    )
    
    rewards = []
    obs, _ = env.reset()
    model.learn(total_timesteps=TIMESTEPS)

    for ep in range(EPISODES):
        obs, _ = env.reset()
        done = False
        total_r = 0
        while not done:
            action, _ = model.predict(obs, deterministic=True)
            obs, reward, done, _, info = env.step(action)
            total_r += reward
        rewards.append(total_r)

    all_rewards.append(rewards)

    # Plotting individual curve
    plt.figure(figsize=(12, 5))
    plt.plot(rewards, label=f"Config #{idx}")
    plt.xlabel("Episode")
    plt.ylabel("Total Reward")
    plt.title(f"SAC Rewards - Config #{idx}")
    plt.legend()
    plt.grid(True)
    plt.savefig(f"sac_rewards_config_{idx:02}.png")
    plt.close()

print("✅ All configs trained and saved.")
# Out:
# Training config #1...
# Training config #2...
# Training config #3...
# Training config #4...
# Training config #5...
# Training config #6...
# Training config #7...
# Training config #8...
# Training config #9...
# Training config #10...
# Training config #11...

# %%
from envs.aquaculture_env import AquacultureEnv
from stable_baselines3 import SAC
from stable_baselines3.common.env_checker import check_env
import torch

print(torch.cuda.is_available())
env = AquacultureEnv(region="north_sulawesi")
check_env(env)

# SAC Model
model = SAC(
    "MlpPolicy",
    env,
    verbose=1,
    tensorboard_log="./aqua_tensorboard",
    learning_rate=1e-4,
    batch_size=256,
    gamma=0.99,
    device="cuda"
)

model.learn(total_timesteps=180 * 300)
# Out:
# False
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# c:\Users\Asus\miniconda3\Lib\site-packages\stable_baselines3\common\env_checker.py:462: UserWarning: We recommend you to use a symmetric and normalized Box action space (range=[-1, 1]) cf. https://stable-baselines3.readthedocs.io/en/master/guide/rl_tips.html
#   warnings.warn(
# Logging to ./aqua_tensorboard\SAC_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | -49.2    |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 62       |
# |    time_elapsed    | 11       |
# |    total_timesteps | 720      |
# | train/             |          |
# |    actor_loss      | -6.88    |
# |    critic_loss     | 0.262    |
# |    ent_coef        | 0.941    |
# |    ent_coef_loss   | -0.286   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 619      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | -38.1    |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 55       |
# |    time_elapsed    | 25       |
# |    total_timesteps | 1440     |
# | train/             |          |
# |    actor_loss      | -11.5    |
# |    critic_loss     | 0.886    |
# |    ent_coef        | 0.877    |
# |    ent_coef_loss   | -0.619   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 1339     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | -32.6    |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 53       |
# |    time_elapsed    | 40       |
# |    total_timesteps | 2160     |
# | train/             |          |
# |    actor_loss      | -15.3    |
# |    critic_loss     | 0.358    |
# |    ent_coef        | 0.816    |
# |    ent_coef_loss   | -0.944   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 2059     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | -27.5    |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 52       |
# |    time_elapsed    | 54       |
# |    total_timesteps | 2880     |
# | train/             |          |
# |    actor_loss      | -18.9    |
# |    critic_loss     | 0.404    |
# |    ent_coef        | 0.76     |
# |    ent_coef_loss   | -1.27    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 2779     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | -21.4    |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 52       |
# |    time_elapsed    | 68       |
# |    total_timesteps | 3600     |
# | train/             |          |
# |    actor_loss      | -22.1    |
# |    critic_loss     | 0.405    |
# |    ent_coef        | 0.708    |
# |    ent_coef_loss   | -1.52    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 3499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | -17.6    |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 52       |
# |    time_elapsed    | 82       |
# |    total_timesteps | 4320     |
# | train/             |          |
# |    actor_loss      | -24.7    |
# |    critic_loss     | 0.567    |
# |    ent_coef        | 0.66     |
# |    ent_coef_loss   | -1.83    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 4219     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | -12.7    |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 52       |
# |    time_elapsed    | 95       |
# |    total_timesteps | 5040     |
# | train/             |          |
# |    actor_loss      | -26.8    |
# |    critic_loss     | 3.29     |
# |    ent_coef        | 0.616    |
# |    ent_coef_loss   | -2.06    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 4939     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | -8.22    |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 52       |
# |    time_elapsed    | 110      |
# |    total_timesteps | 5760     |
# | train/             |          |
# |    actor_loss      | -28.7    |
# |    critic_loss     | 6.46     |
# |    ent_coef        | 0.575    |
# |    ent_coef_loss   | -2.22    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 5659     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | -3.78    |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 52       |
# |    time_elapsed    | 123      |
# |    total_timesteps | 6480     |
# | train/             |          |
# |    actor_loss      | -30.4    |
# |    critic_loss     | 3.67     |
# |    ent_coef        | 0.537    |
# |    ent_coef_loss   | -2.4     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 6379     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 0.6      |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 51       |
# |    time_elapsed    | 139      |
# |    total_timesteps | 7200     |
# | train/             |          |
# |    actor_loss      | -32.1    |
# |    critic_loss     | 0.997    |
# |    ent_coef        | 0.501    |
# |    ent_coef_loss   | -2.5     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 7099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 5.08     |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 49       |
# |    time_elapsed    | 158      |
# |    total_timesteps | 7920     |
# | train/             |          |
# |    actor_loss      | -33.8    |
# |    critic_loss     | 5.16     |
# |    ent_coef        | 0.468    |
# |    ent_coef_loss   | -2.82    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 7819     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 9.06     |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 49       |
# |    time_elapsed    | 173      |
# |    total_timesteps | 8640     |
# | train/             |          |
# |    actor_loss      | -34.9    |
# |    critic_loss     | 9.86     |
# |    ent_coef        | 0.437    |
# |    ent_coef_loss   | -2.87    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 8539     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 11.8     |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 49       |
# |    time_elapsed    | 187      |
# |    total_timesteps | 9360     |
# | train/             |          |
# |    actor_loss      | -35.8    |
# |    critic_loss     | 9.3      |
# |    ent_coef        | 0.408    |
# |    ent_coef_loss   | -3.12    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 9259     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 15       |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 50       |
# |    time_elapsed    | 200      |
# |    total_timesteps | 10080    |
# | train/             |          |
# |    actor_loss      | -37.3    |
# |    critic_loss     | 10.1     |
# |    ent_coef        | 0.381    |
# |    ent_coef_loss   | -2.96    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 9979     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 17.9     |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 50       |
# |    time_elapsed    | 214      |
# |    total_timesteps | 10800    |
# | train/             |          |
# |    actor_loss      | -38.1    |
# |    critic_loss     | 7.05     |
# |    ent_coef        | 0.356    |
# |    ent_coef_loss   | -3.25    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 10699    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 20.1     |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 50       |
# |    time_elapsed    | 227      |
# |    total_timesteps | 11520    |
# | train/             |          |
# |    actor_loss      | -38.6    |
# |    critic_loss     | 1.11     |
# |    ent_coef        | 0.333    |
# |    ent_coef_loss   | -3.22    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 11419    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 22.5     |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 50       |
# |    time_elapsed    | 240      |
# |    total_timesteps | 12240    |
# | train/             |          |
# |    actor_loss      | -38.8    |
# |    critic_loss     | 12.3     |
# |    ent_coef        | 0.311    |
# |    ent_coef_loss   | -3.34    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 12139    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 24.7     |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 51       |
# |    time_elapsed    | 253      |
# |    total_timesteps | 12960    |
# | train/             |          |
# |    actor_loss      | -39.6    |
# |    critic_loss     | 1.07     |
# |    ent_coef        | 0.29     |
# |    ent_coef_loss   | -3.5     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 12859    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 26.7     |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 51       |
# |    time_elapsed    | 265      |
# |    total_timesteps | 13680    |
# | train/             |          |
# |    actor_loss      | -39.8    |
# |    critic_loss     | 18.9     |
# |    ent_coef        | 0.271    |
# |    ent_coef_loss   | -3.41    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 13579    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 28.6     |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 51       |
# |    time_elapsed    | 279      |
# |    total_timesteps | 14400    |
# | train/             |          |
# |    actor_loss      | -40.1    |
# |    critic_loss     | 18.9     |
# |    ent_coef        | 0.253    |
# |    ent_coef_loss   | -3.54    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 14299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 30.5     |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 51       |
# |    time_elapsed    | 294      |
# |    total_timesteps | 15120    |
# | train/             |          |
# |    actor_loss      | -40.1    |
# |    critic_loss     | 14.9     |
# |    ent_coef        | 0.237    |
# |    ent_coef_loss   | -3.87    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 15019    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 31.6     |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 51       |
# |    time_elapsed    | 307      |
# |    total_timesteps | 15840    |
# | train/             |          |
# |    actor_loss      | -40.3    |
# |    critic_loss     | 8.13     |
# |    ent_coef        | 0.221    |
# |    ent_coef_loss   | -3.63    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 15739    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 32.8     |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 50       |
# |    time_elapsed    | 324      |
# |    total_timesteps | 16560    |
# | train/             |          |
# |    actor_loss      | -40.4    |
# |    critic_loss     | 7.29     |
# |    ent_coef        | 0.207    |
# |    ent_coef_loss   | -3.52    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 16459    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 33.7     |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 50       |
# |    time_elapsed    | 340      |
# |    total_timesteps | 17280    |
# | train/             |          |
# |    actor_loss      | -40.2    |
# |    critic_loss     | 13.6     |
# |    ent_coef        | 0.194    |
# |    ent_coef_loss   | -3.72    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 17179    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 35       |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 50       |
# |    time_elapsed    | 357      |
# |    total_timesteps | 18000    |
# | train/             |          |
# |    actor_loss      | -40.2    |
# |    critic_loss     | 7.07     |
# |    ent_coef        | 0.181    |
# |    ent_coef_loss   | -3.78    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 17899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 39.5     |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 49       |
# |    time_elapsed    | 374      |
# |    total_timesteps | 18720    |
# | train/             |          |
# |    actor_loss      | -40.8    |
# |    critic_loss     | 6.97     |
# |    ent_coef        | 0.169    |
# |    ent_coef_loss   | -3.18    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 18619    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 43.2     |
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 49       |
# |    time_elapsed    | 389      |
# |    total_timesteps | 19440    |
# | train/             |          |
# |    actor_loss      | -40.9    |
# |    critic_loss     | 7.23     |
# |    ent_coef        | 0.158    |
# |    ent_coef_loss   | -3.08    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 19339    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 46.8     |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 49       |
# |    time_elapsed    | 404      |
# |    total_timesteps | 20160    |
# | train/             |          |
# |    actor_loss      | -40.5    |
# |    critic_loss     | 10.8     |
# |    ent_coef        | 0.148    |
# |    ent_coef_loss   | -3.34    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 20059    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 50       |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 49       |
# |    time_elapsed    | 419      |
# |    total_timesteps | 20880    |
# | train/             |          |
# |    actor_loss      | -40.9    |
# |    critic_loss     | 22.2     |
# |    ent_coef        | 0.139    |
# |    ent_coef_loss   | -3.35    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 20779    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 52.4     |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 49       |
# |    time_elapsed    | 433      |
# |    total_timesteps | 21600    |
# | train/             |          |
# |    actor_loss      | -40.6    |
# |    critic_loss     | 1.64     |
# |    ent_coef        | 0.13     |
# |    ent_coef_loss   | -3.47    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 21499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 55.2     |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 50       |
# |    time_elapsed    | 443      |
# |    total_timesteps | 22320    |
# | train/             |          |
# |    actor_loss      | -40.5    |
# |    critic_loss     | 7.72     |
# |    ent_coef        | 0.122    |
# |    ent_coef_loss   | -3.24    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 22219    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 57.2     |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 50       |
# |    time_elapsed    | 455      |
# |    total_timesteps | 23040    |
# | train/             |          |
# |    actor_loss      | -40.8    |
# |    critic_loss     | 6.77     |
# |    ent_coef        | 0.115    |
# |    ent_coef_loss   | -2.24    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 22939    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 59       |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 50       |
# |    time_elapsed    | 470      |
# |    total_timesteps | 23760    |
# | train/             |          |
# |    actor_loss      | -40.4    |
# |    critic_loss     | 8.11     |
# |    ent_coef        | 0.109    |
# |    ent_coef_loss   | -2.25    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 23659    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 60.3     |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 50       |
# |    time_elapsed    | 486      |
# |    total_timesteps | 24480    |
# | train/             |          |
# |    actor_loss      | -40.3    |
# |    critic_loss     | 13.7     |
# |    ent_coef        | 0.102    |
# |    ent_coef_loss   | -1.47    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 24379    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 61.1     |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 50       |
# |    time_elapsed    | 498      |
# |    total_timesteps | 25200    |
# | train/             |          |
# |    actor_loss      | -40.1    |
# |    critic_loss     | 1.48     |
# |    ent_coef        | 0.0959   |
# |    ent_coef_loss   | -2.37    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 25099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 61.7     |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 50       |
# |    time_elapsed    | 510      |
# |    total_timesteps | 25920    |
# | train/             |          |
# |    actor_loss      | -40.4    |
# |    critic_loss     | 7.86     |
# |    ent_coef        | 0.0904   |
# |    ent_coef_loss   | -1.33    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 25819    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 62.3     |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 50       |
# |    time_elapsed    | 522      |
# |    total_timesteps | 26640    |
# | train/             |          |
# |    actor_loss      | -40.3    |
# |    critic_loss     | 7.74     |
# |    ent_coef        | 0.0853   |
# |    ent_coef_loss   | -1.3     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 26539    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 63.4     |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 51       |
# |    time_elapsed    | 532      |
# |    total_timesteps | 27360    |
# | train/             |          |
# |    actor_loss      | -40      |
# |    critic_loss     | 2.12     |
# |    ent_coef        | 0.0806   |
# |    ent_coef_loss   | -0.812   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 27259    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 63.8     |
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 51       |
# |    time_elapsed    | 543      |
# |    total_timesteps | 28080    |
# | train/             |          |
# |    actor_loss      | -40.5    |
# |    critic_loss     | 12.8     |
# |    ent_coef        | 0.0761   |
# |    ent_coef_loss   | -1.76    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 27979    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 64.1     |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 52       |
# |    time_elapsed    | 553      |
# |    total_timesteps | 28800    |
# | train/             |          |
# |    actor_loss      | -40.8    |
# |    critic_loss     | 8.22     |
# |    ent_coef        | 0.0718   |
# |    ent_coef_loss   | -2.06    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 28699    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 64.9     |
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 52       |
# |    time_elapsed    | 565      |
# |    total_timesteps | 29520    |
# | train/             |          |
# |    actor_loss      | -40.2    |
# |    critic_loss     | 16       |
# |    ent_coef        | 0.0681   |
# |    ent_coef_loss   | -1.01    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 29419    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 65.1     |
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 52       |
# |    time_elapsed    | 579      |
# |    total_timesteps | 30240    |
# | train/             |          |
# |    actor_loss      | -40.1    |
# |    critic_loss     | 14.7     |
# |    ent_coef        | 0.0644   |
# |    ent_coef_loss   | -0.78    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 30139    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 65.1     |
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 52       |
# |    time_elapsed    | 594      |
# |    total_timesteps | 30960    |
# | train/             |          |
# |    actor_loss      | -40.1    |
# |    critic_loss     | 8.1      |
# |    ent_coef        | 0.0616   |
# |    ent_coef_loss   | -1.1     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 30859    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 65.2     |
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 52       |
# |    time_elapsed    | 608      |
# |    total_timesteps | 31680    |
# | train/             |          |
# |    actor_loss      | -40.9    |
# |    critic_loss     | 6.01     |
# |    ent_coef        | 0.0605   |
# |    ent_coef_loss   | -0.119   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 31579    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 65       |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 51       |
# |    time_elapsed    | 623      |
# |    total_timesteps | 32400    |
# | train/             |          |
# |    actor_loss      | -40.4    |
# |    critic_loss     | 21       |
# |    ent_coef        | 0.0591   |
# |    ent_coef_loss   | 0.549    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 32299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 65       |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 52       |
# |    time_elapsed    | 633      |
# |    total_timesteps | 33120    |
# | train/             |          |
# |    actor_loss      | -40.5    |
# |    critic_loss     | 14       |
# |    ent_coef        | 0.0583   |
# |    ent_coef_loss   | -0.859   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 33019    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 65.5     |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 52       |
# |    time_elapsed    | 643      |
# |    total_timesteps | 33840    |
# | train/             |          |
# |    actor_loss      | -40.8    |
# |    critic_loss     | 27.2     |
# |    ent_coef        | 0.0564   |
# |    ent_coef_loss   | -0.0925  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 33739    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 65.6     |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 52       |
# |    time_elapsed    | 654      |
# |    total_timesteps | 34560    |
# | train/             |          |
# |    actor_loss      | -40.8    |
# |    critic_loss     | 8.54     |
# |    ent_coef        | 0.0554   |
# |    ent_coef_loss   | -0.445   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 34459    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 65.9     |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 52       |
# |    time_elapsed    | 668      |
# |    total_timesteps | 35280    |
# | train/             |          |
# |    actor_loss      | -41      |
# |    critic_loss     | 1.75     |
# |    ent_coef        | 0.0551   |
# |    ent_coef_loss   | 0.361    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 35179    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 65.7     |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 52       |
# |    time_elapsed    | 681      |
# |    total_timesteps | 36000    |
# | train/             |          |
# |    actor_loss      | -40.7    |
# |    critic_loss     | 16       |
# |    ent_coef        | 0.0543   |
# |    ent_coef_loss   | -0.445   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 35899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 65.6     |
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 52       |
# |    time_elapsed    | 693      |
# |    total_timesteps | 36720    |
# | train/             |          |
# |    actor_loss      | -41.3    |
# |    critic_loss     | 1.85     |
# |    ent_coef        | 0.0542   |
# |    ent_coef_loss   | 1.13     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 36619    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 65.3     |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 52       |
# |    time_elapsed    | 708      |
# |    total_timesteps | 37440    |
# | train/             |          |
# |    actor_loss      | -41.9    |
# |    critic_loss     | 21       |
# |    ent_coef        | 0.0543   |
# |    ent_coef_loss   | 0.974    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 37339    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 64.7     |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 52       |
# |    time_elapsed    | 722      |
# |    total_timesteps | 38160    |
# | train/             |          |
# |    actor_loss      | -40.6    |
# |    critic_loss     | 2.84     |
# |    ent_coef        | 0.0561   |
# |    ent_coef_loss   | -0.0165  |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 38059    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 64.2     |
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 52       |
# |    time_elapsed    | 735      |
# |    total_timesteps | 38880    |
# | train/             |          |
# |    actor_loss      | -41.1    |
# |    critic_loss     | 21.5     |
# |    ent_coef        | 0.0584   |
# |    ent_coef_loss   | 1        |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 38779    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 64       |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 52       |
# |    time_elapsed    | 749      |
# |    total_timesteps | 39600    |
# | train/             |          |
# |    actor_loss      | -41.2    |
# |    critic_loss     | 15.4     |
# |    ent_coef        | 0.0615   |
# |    ent_coef_loss   | 0.502    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 39499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 63.8     |
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 52       |
# |    time_elapsed    | 764      |
# |    total_timesteps | 40320    |
# | train/             |          |
# |    actor_loss      | -41.6    |
# |    critic_loss     | 8.31     |
# |    ent_coef        | 0.0634   |
# |    ent_coef_loss   | 1.35     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 40219    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 63.9     |
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 52       |
# |    time_elapsed    | 777      |
# |    total_timesteps | 41040    |
# | train/             |          |
# |    actor_loss      | -40.7    |
# |    critic_loss     | 29       |
# |    ent_coef        | 0.0648   |
# |    ent_coef_loss   | 0.314    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 40939    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 63.8     |
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 52       |
# |    time_elapsed    | 789      |
# |    total_timesteps | 41760    |
# | train/             |          |
# |    actor_loss      | -40.4    |
# |    critic_loss     | 2.11     |
# |    ent_coef        | 0.0642   |
# |    ent_coef_loss   | -0.5     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 41659    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 64.1     |
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 53       |
# |    time_elapsed    | 800      |
# |    total_timesteps | 42480    |
# | train/             |          |
# |    actor_loss      | -40.6    |
# |    critic_loss     | 3.03     |
# |    ent_coef        | 0.0641   |
# |    ent_coef_loss   | 0.361    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 42379    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 64.3     |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 53       |
# |    time_elapsed    | 812      |
# |    total_timesteps | 43200    |
# | train/             |          |
# |    actor_loss      | -40.6    |
# |    critic_loss     | 2.28     |
# |    ent_coef        | 0.0635   |
# |    ent_coef_loss   | 0.524    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 43099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 64.5     |
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 53       |
# |    time_elapsed    | 823      |
# |    total_timesteps | 43920    |
# | train/             |          |
# |    actor_loss      | -40.1    |
# |    critic_loss     | 8.81     |
# |    ent_coef        | 0.0632   |
# |    ent_coef_loss   | -0.233   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 43819    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 64.5     |
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 53       |
# |    time_elapsed    | 836      |
# |    total_timesteps | 44640    |
# | train/             |          |
# |    actor_loss      | -40      |
# |    critic_loss     | 18.8     |
# |    ent_coef        | 0.0635   |
# |    ent_coef_loss   | -0.248   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 44539    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 64.3     |
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 53       |
# |    time_elapsed    | 849      |
# |    total_timesteps | 45360    |
# | train/             |          |
# |    actor_loss      | -39.4    |
# |    critic_loss     | 21.3     |
# |    ent_coef        | 0.0641   |
# |    ent_coef_loss   | 0.327    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 45259    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 64.3     |
# | time/              |          |
# |    episodes        | 256      |
# |    fps             | 53       |
# |    time_elapsed    | 861      |
# |    total_timesteps | 46080    |
# | train/             |          |
# |    actor_loss      | -39.6    |
# |    critic_loss     | 13.1     |
# |    ent_coef        | 0.0659   |
# |    ent_coef_loss   | 0.535    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 45979    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 64.2     |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 53       |
# |    time_elapsed    | 872      |
# |    total_timesteps | 46800    |
# | train/             |          |
# |    actor_loss      | -39.4    |
# |    critic_loss     | 13.2     |
# |    ent_coef        | 0.0685   |
# |    ent_coef_loss   | 0.19     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 46699    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 64.2     |
# | time/              |          |
# |    episodes        | 264      |
# |    fps             | 53       |
# |    time_elapsed    | 886      |
# |    total_timesteps | 47520    |
# | train/             |          |
# |    actor_loss      | -39.2    |
# |    critic_loss     | 2.75     |
# |    ent_coef        | 0.0702   |
# |    ent_coef_loss   | 0.199    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 47419    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 64.2     |
# | time/              |          |
# |    episodes        | 268      |
# |    fps             | 53       |
# |    time_elapsed    | 901      |
# |    total_timesteps | 48240    |
# | train/             |          |
# |    actor_loss      | -39.3    |
# |    critic_loss     | 8.31     |
# |    ent_coef        | 0.073    |
# |    ent_coef_loss   | -0.485   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 48139    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 64.3     |
# | time/              |          |
# |    episodes        | 272      |
# |    fps             | 53       |
# |    time_elapsed    | 912      |
# |    total_timesteps | 48960    |
# | train/             |          |
# |    actor_loss      | -39.9    |
# |    critic_loss     | 1.45     |
# |    ent_coef        | 0.0748   |
# |    ent_coef_loss   | 0.498    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 48859    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 64.5     |
# | time/              |          |
# |    episodes        | 276      |
# |    fps             | 53       |
# |    time_elapsed    | 926      |
# |    total_timesteps | 49680    |
# | train/             |          |
# |    actor_loss      | -38.2    |
# |    critic_loss     | 7.21     |
# |    ent_coef        | 0.0746   |
# |    ent_coef_loss   | -0.792   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 49579    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 65       |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 53       |
# |    time_elapsed    | 940      |
# |    total_timesteps | 50400    |
# | train/             |          |
# |    actor_loss      | -38.9    |
# |    critic_loss     | 4.71     |
# |    ent_coef        | 0.0759   |
# |    ent_coef_loss   | 0.789    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 50299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 65       |
# | time/              |          |
# |    episodes        | 284      |
# |    fps             | 53       |
# |    time_elapsed    | 954      |
# |    total_timesteps | 51120    |
# | train/             |          |
# |    actor_loss      | -38.5    |
# |    critic_loss     | 1.76     |
# |    ent_coef        | 0.0769   |
# |    ent_coef_loss   | 0.0474   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 51019    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 65.2     |
# | time/              |          |
# |    episodes        | 288      |
# |    fps             | 53       |
# |    time_elapsed    | 968      |
# |    total_timesteps | 51840    |
# | train/             |          |
# |    actor_loss      | -38.3    |
# |    critic_loss     | 4.38     |
# |    ent_coef        | 0.079    |
# |    ent_coef_loss   | 0.837    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 51739    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 65.5     |
# | time/              |          |
# |    episodes        | 292      |
# |    fps             | 53       |
# |    time_elapsed    | 981      |
# |    total_timesteps | 52560    |
# | train/             |          |
# |    actor_loss      | -37.5    |
# |    critic_loss     | 1.44     |
# |    ent_coef        | 0.0795   |
# |    ent_coef_loss   | 0.618    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 52459    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 65.7     |
# | time/              |          |
# |    episodes        | 296      |
# |    fps             | 53       |
# |    time_elapsed    | 993      |
# |    total_timesteps | 53280    |
# | train/             |          |
# |    actor_loss      | -36.9    |
# |    critic_loss     | 12.6     |
# |    ent_coef        | 0.0787   |
# |    ent_coef_loss   | -0.362   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 53179    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 66.2     |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 53       |
# |    time_elapsed    | 1004     |
# |    total_timesteps | 54000    |
# | train/             |          |
# |    actor_loss      | -36.9    |
# |    critic_loss     | 19.7     |
# |    ent_coef        | 0.0803   |
# |    ent_coef_loss   | -0.617   |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 53899    |
# ---------------------------------

# %%
import time
from utils.calculation import Calculation

obs, _ = env.reset()
terminated = False
truncated = False
total_reward = 0

print("Action space:", env.action_space)

while not (terminated or truncated):
    action, states = model.predict(obs, deterministic=True)
    raw = env.denormalize(obs)
    biomass, fish_count, temp, do_level, uia = raw
    feed_amount = Calculation.compute_feed_weight(action[0], biomass)
    print(f"""\n--- Day {env.day + 1} ---
Raw-obs: biomass={biomass:.1f} g, count={fish_count:.0f}, temp={temp:.2f}°C, DO={do_level:.2f} mg/L, UIA={uia:.3f} mg/L
Action: feed_rate={action[0]:.3f} → feed_amt={feed_amount:.2f} g, temp_set={action[1]:.3f}, aeration_rate={action[2]:.2f}mg/L
""")

    obs, reward, terminated, truncated, info = env.step(action)
    total_reward += reward

    print(f"""Reward Breakdown:
Fish Value Gain:     {info['fish_value']} $
Feed Cost:           {info['feed_cost']:.2f} $
Heat Cost:           {info['heat_cost']:.2f} $
Oxygenation Cost:    {info['oxygenation_cost']:.2f} $
→ Net Reward:        {info['reward']:.2f} $
""")

    env.render()

    if hasattr(env, 'exit_requested') and env.exit_requested:
        break

    time.sleep(0.01)

env.close()
print("Total Reward:", total_reward)
# Out:
# Action space: Box([ 0.  24.   0.3], [ 1. 40.  1.], (3,), float32)
#
# --- Day 1 ---
# Raw-obs: biomass=1349.0 g, count=100, temp=24.00°C, DO=0.60 mg/L, UIA=0.060 mg/L
# Action: feed_rate=0.954 → feed_amt=128.73 g, temp_set=39.346, aeration_rate=0.89mg/L
#
# Reward Breakdown:
# Fish Value Gain:     0.14317488889083824 $
# Feed Cost:           0.15 $
# Heat Cost:           2.35 $
# Oxygenation Cost:    0.19 $
# → Net Reward:        -1.76 $
#
#
# --- Day 2 ---
# Raw-obs: biomass=1386.9 g, count=100, temp=27.44°C, DO=0.89 mg/L, UIA=0.060 mg/L
# Action: feed_rate=0.941 → feed_amt=130.47 g, temp_set=39.572, aeration_rate=0.84mg/L
#
# Reward Breakdown:
# Fish Value Gain:     0.2594268597669848 $
# Feed Cost:           0.15 $
# Heat Cost:           2.36 $
# Oxygenation Cost:    0.18 $
# → Net Reward:        -1.53 $
#
#
# --- Day 3 ---
# Raw-obs: biomass=1455.5 g, count=100, temp=29.85°C, DO=0.84 mg/L, UIA=0.060 mg/L
# Action: feed_rate=0.941 → feed_amt=136.93 g, temp_set=39.413, aeration_rate=0.88mg/L
#
# Reward Breakdown:
# Fish Value Gain:     0.30448422552221255 $
# Feed Cost:           0.16 $
# Heat Cost:           2.55 $
# Oxygenation Cost:    0.19 $
# → Net Reward:        -1.59 $
#
#
# --- Day 4 ---
# Raw-obs: biomass=1536.0 g, count=100, temp=31.54°C, DO=0.88 mg/L, UIA=0.064 mg/L
# Action: feed_rate=0.940 → feed_amt=144.43 g, temp_set=35.442, aeration_rate=0.88mg/L
#
# Reward Breakdown:
# Fish Value Gain:     0.31787010865882176 $
# Feed Cost:           0.17 $
# Heat Cost:           2.10 $
# Oxygenation Cost:    0.19 $
# → Net Reward:        -1.23 $
#
#
# --- Day 5 ---
# Raw-obs: biomass=1620.1 g, count=100, temp=31.78°C, DO=0.88 mg/L, UIA=0.070 mg/L
# Action: feed_rate=0.941 → feed_amt=152.49 g, temp_set=33.273, aeration_rate=0.88mg/L
#
# Reward Breakdown:
# Fish Value Gain:     0.32823683397314185 $
# Feed Cost:           0.18 $
# Heat Cost:           1.85 $
# Oxygenation Cost:    0.19 $
# → Net Reward:        -1.04 $
#
#
# --- Day 6 ---
# Raw-obs: biomass=1707.0 g, count=100, temp=31.35°C, DO=0.88 mg/L, UIA=0.072 mg/L
# Action: feed_rate=0.944 → feed_amt=161.16 g, temp_set=35.999, aeration_rate=0.89mg/L
#
# Reward Breakdown:
# Fish Value Gain:     0.3405061982027229 $
# Feed Cost:           0.19 $
# Heat Cost:           2.28 $
# Oxygenation Cost:    0.19 $
# → Net Reward:        -1.35 $
#
#
# --- Day 7 ---
# Raw-obs: biomass=1797.1 g, count=100, temp=31.79°C, DO=0.89 mg/L, UIA=0.078 mg/L
# Action: feed_rate=0.944 → feed_amt=169.66 g, temp_set=32.468, aeration_rate=0.89mg/L
#
# Reward Breakdown:
# Fish Value Gain:     0.3488307206460305 $
# Feed Cost:           0.20 $
# Heat Cost:           2.03 $
# Oxygenation Cost:    0.19 $
# → Net Reward:        -1.15 $
#
#
# --- Day 8 ---
# Raw-obs: biomass=1889.3 g, count=100, temp=31.12°C, DO=0.89 mg/L, UIA=0.079 mg/L
# Action: feed_rate=0.946 → feed_amt=178.75 g, temp_set=36.709, aeration_rate=0.89mg/L
#
# Reward Breakdown:
# Fish Value Gain:     0.3625646568611567 $
# Feed Cost:           0.21 $
# Heat Cost:           2.23 $
# Oxygenation Cost:    0.19 $
# → Net Reward:        -1.28 $
#
#
# --- Day 9 ---
# Raw-obs: biomass=1985.3 g, count=100, temp=31.66°C, DO=0.89 mg/L, UIA=0.085 mg/L
# Action: feed_rate=0.947 → feed_amt=187.95 g, temp_set=32.833, aeration_rate=0.89mg/L
#
# Reward Breakdown:
# Fish Value Gain:     0.37139233129713095 $
# Feed Cost:           0.22 $
# Heat Cost:           1.76 $
# Oxygenation Cost:    0.19 $
# → Net Reward:        -0.92 $
#
#
# --- Day 10 ---
# Raw-obs: biomass=2083.5 g, count=100, temp=31.13°C, DO=0.89 mg/L, UIA=0.087 mg/L
# Action: feed_rate=0.948 → feed_amt=197.53 g, temp_set=36.195, aeration_rate=0.90mg/L
#
# Reward Breakdown:
# Fish Value Gain:     0.3858514402035138 $
# Feed Cost:           0.23 $
# Heat Cost:           2.10 $
# Oxygenation Cost:    0.19 $
# → Net Reward:        -1.15 $
#
#
# --- Day 11 ---
# Raw-obs: biomass=2185.6 g, count=100, temp=31.69°C, DO=0.90 mg/L, UIA=0.093 mg/L
# Action: feed_rate=0.949 → feed_amt=207.32 g, temp_set=31.771, aeration_rate=0.90mg/L
#
# Reward Breakdown:
# Fish Value Gain:     0.3920710910632084 $
# Feed Cost:           0.24 $
# Heat Cost:           1.77 $
# Oxygenation Cost:    0.19 $
# → Net Reward:        -0.90 $
#
#
# --- Day 12 ---
# Raw-obs: biomass=2289.3 g, count=100, temp=30.89°C, DO=0.90 mg/L, UIA=0.094 mg/L
# Action: feed_rate=0.950 → feed_amt=217.47 g, temp_set=36.965, aeration_rate=0.90mg/L
#
# Reward Breakdown:
# Fish Value Gain:     0.4085677751171956 $
# Feed Cost:           0.26 $
# Heat Cost:           2.03 $
# Oxygenation Cost:    0.19 $
# → Net Reward:        -1.08 $
#
#
# --- Day 13 ---
# Raw-obs: biomass=2397.4 g, count=100, temp=31.68°C, DO=0.90 mg/L, UIA=0.102 mg/L
# Action: feed_rate=0.950 → feed_amt=227.84 g, temp_set=31.013, aeration_rate=0.90mg/L
#
# Reward Breakdown:
# Fish Value Gain:     0.41519921343466576 $
# Feed Cost:           0.27 $
# Heat Cost:           1.47 $
# Oxygenation Cost:    0.19 $
# → Net Reward:        -0.66 $
#
#
# --- Day 14 ---
# Raw-obs: biomass=2507.2 g, count=100, temp=30.88°C, DO=0.90 mg/L, UIA=0.102 mg/L
# Action: feed_rate=0.952 → feed_amt=238.66 g, temp_set=36.560, aeration_rate=0.90mg/L
#
# Reward Breakdown:
# Fish Value Gain:     0.43210950013840455 $
# Feed Cost:           0.28 $
# Heat Cost:           1.99 $
# Oxygenation Cost:    0.19 $
# → Net Reward:        -1.03 $
#
#
# --- Day 15 ---
# Raw-obs: biomass=2621.6 g, count=100, temp=31.55°C, DO=0.90 mg/L, UIA=0.110 mg/L
# Action: feed_rate=0.952 → feed_amt=249.68 g, temp_set=31.208, aeration_rate=0.91mg/L
#
# Reward Breakdown:
# Fish Value Gain:     0.4377495189699284 $
# Feed Cost:           0.29 $
# Heat Cost:           1.48 $
# Oxygenation Cost:    0.20 $
# → Net Reward:        -0.64 $
#
#
# --- Day 16 ---
# Raw-obs: biomass=2737.4 g, count=100, temp=30.79°C, DO=0.91 mg/L, UIA=0.111 mg/L
# Action: feed_rate=0.954 → feed_amt=261.06 g, temp_set=36.497, aeration_rate=0.91mg/L
#
# Reward Breakdown:
# Fish Value Gain:     0.4554732452461363 $
# Feed Cost:           0.31 $
# Heat Cost:           2.04 $
# Oxygenation Cost:    0.20 $
# → Net Reward:        -1.04 $
#
#
# --- Day 17 ---
# Raw-obs: biomass=2857.9 g, count=100, temp=31.48°C, DO=0.91 mg/L, UIA=0.119 mg/L
# Action: feed_rate=0.954 → feed_amt=272.72 g, temp_set=30.888, aeration_rate=0.91mg/L
#
# Reward Breakdown:
# Fish Value Gain:     0.46094359294944837 $
# Feed Cost:           0.32 $
# Heat Cost:           1.47 $
# Oxygenation Cost:    0.20 $
# → Net Reward:        -0.62 $
#
#
# --- Day 18 ---
# Raw-obs: biomass=2979.8 g, count=100, temp=30.75°C, DO=0.91 mg/L, UIA=0.120 mg/L
# Action: feed_rate=0.955 → feed_amt=284.69 g, temp_set=36.109, aeration_rate=0.91mg/L
#
# Reward Breakdown:
# Fish Value Gain:     0.47914206637678425 $
# Feed Cost:           0.33 $
# Heat Cost:           1.96 $
# Oxygenation Cost:    0.20 $
# → Net Reward:        -0.96 $
#
#
# --- Day 19 ---
# Raw-obs: biomass=3106.6 g, count=100, temp=31.41°C, DO=0.91 mg/L, UIA=0.129 mg/L
# Action: feed_rate=0.955 → feed_amt=296.81 g, temp_set=30.547, aeration_rate=0.92mg/L
#
# Reward Breakdown:
# Fish Value Gain:     0.48292661598960196 $
# Feed Cost:           0.35 $
# Heat Cost:           1.54 $
# Oxygenation Cost:    0.20 $
# → Net Reward:        -0.65 $
#
#
# --- Day 20 ---
# Raw-obs: biomass=3234.3 g, count=100, temp=30.62°C, DO=0.92 mg/L, UIA=0.129 mg/L
# Action: feed_rate=0.957 → feed_amt=309.37 g, temp_set=36.156, aeration_rate=0.92mg/L
#
# Reward Breakdown:
# Fish Value Gain:     0.5020974264420515 $
# Feed Cost:           0.36 $
# Heat Cost:           1.93 $
# Oxygenation Cost:    0.20 $
# → Net Reward:        -0.92 $
#
#
# --- Day 21 ---
# Raw-obs: biomass=3367.1 g, count=100, temp=31.24°C, DO=0.92 mg/L, UIA=0.137 mg/L
# Action: feed_rate=0.956 → feed_amt=321.94 g, temp_set=31.034, aeration_rate=0.92mg/L
#
# Reward Breakdown:
# Fish Value Gain:     0.5057978732430081 $
# Feed Cost:           0.37 $
# Heat Cost:           1.53 $
# Oxygenation Cost:    0.20 $
# → Net Reward:        -0.62 $
#
#
# --- Day 22 ---
# Raw-obs: biomass=3501.0 g, count=100, temp=30.53°C, DO=0.92 mg/L, UIA=0.138 mg/L
# Action: feed_rate=0.957 → feed_amt=335.05 g, temp_set=35.973, aeration_rate=0.92mg/L
#
# Reward Breakdown:
# Fish Value Gain:     0.5254469433521965 $
# Feed Cost:           0.39 $
# Heat Cost:           2.06 $
# Oxygenation Cost:    0.20 $
# → Net Reward:        -0.99 $
#
#
# --- Day 23 ---
# Raw-obs: biomass=3640.0 g, count=100, temp=31.12°C, DO=0.92 mg/L, UIA=0.146 mg/L
# Action: feed_rate=0.957 → feed_amt=348.21 g, temp_set=31.065, aeration_rate=0.92mg/L
#
# Reward Breakdown:
# Fish Value Gain:     0.5253793721130273 $
# Feed Cost:           0.40 $
# Heat Cost:           1.43 $
# Oxygenation Cost:    0.20 $
# → Net Reward:        -0.54 $
#
#
# --- Day 24 ---
# Raw-obs: biomass=3778.9 g, count=100, temp=30.34°C, DO=0.92 mg/L, UIA=0.146 mg/L
# Action: feed_rate=0.958 → feed_amt=361.86 g, temp_set=36.396, aeration_rate=0.92mg/L
#
# Reward Breakdown:
# Fish Value Gain:     0.5496860936765148 $
# Feed Cost:           0.42 $
# Heat Cost:           2.01 $
# Oxygenation Cost:    0.20 $
# → Net Reward:        -0.93 $
#
#
# --- Day 25 ---
# Raw-obs: biomass=3924.4 g, count=100, temp=31.15°C, DO=0.92 mg/L, UIA=0.157 mg/L
# Action: feed_rate=0.955 → feed_amt=374.84 g, temp_set=29.784, aeration_rate=0.92mg/L
#
# Reward Breakdown:
# Fish Value Gain:     0.5572236974765825 $
# Feed Cost:           0.44 $
# Heat Cost:           1.32 $
# Oxygenation Cost:    0.20 $
# → Net Reward:        -0.41 $
#
#
# --- Day 26 ---
# Raw-obs: biomass=4071.8 g, count=100, temp=30.54°C, DO=0.92 mg/L, UIA=0.158 mg/L
# Action: feed_rate=0.956 → feed_amt=389.09 g, temp_set=34.215, aeration_rate=0.92mg/L
#
# Reward Breakdown:
# Fish Value Gain:     0.5765275745330127 $
# Feed Cost:           0.45 $
# Heat Cost:           1.77 $
# Oxygenation Cost:    0.20 $
# → Net Reward:        -0.73 $
#
#
# --- Day 27 ---
# Raw-obs: biomass=4224.3 g, count=100, temp=30.89°C, DO=0.92 mg/L, UIA=0.166 mg/L
# Action: feed_rate=0.951 → feed_amt=401.89 g, temp_set=30.985, aeration_rate=0.92mg/L
#
# Reward Breakdown:
# Fish Value Gain:     0.5782406394724823 $
# Feed Cost:           0.47 $
# Heat Cost:           1.43 $
# Oxygenation Cost:    0.20 $
# → Net Reward:        -0.49 $
#
#
# --- Day 28 ---
# Raw-obs: biomass=4377.3 g, count=100, temp=30.13°C, DO=0.92 mg/L, UIA=0.164 mg/L
# Action: feed_rate=0.953 → feed_amt=417.06 g, temp_set=36.169, aeration_rate=0.92mg/L
#
# Reward Breakdown:
# Fish Value Gain:     0.6081790860452448 $
# Feed Cost:           0.48 $
# Heat Cost:           1.86 $
# Oxygenation Cost:    0.20 $
# → Net Reward:        -0.76 $
#
#
# --- Day 29 ---
# Raw-obs: biomass=4538.2 g, count=100, temp=30.93°C, DO=0.92 mg/L, UIA=0.176 mg/L
# Action: feed_rate=0.945 → feed_amt=428.98 g, temp_set=29.795, aeration_rate=0.92mg/L
#
# Reward Breakdown:
# Fish Value Gain:     0.6192951433984241 $
# Feed Cost:           0.50 $
# Heat Cost:           1.44 $
# Oxygenation Cost:    0.20 $
# → Net Reward:        -0.44 $
#
#
# --- Day 30 ---
# Raw-obs: biomass=4702.0 g, count=100, temp=30.25°C, DO=0.92 mg/L, UIA=0.175 mg/L
# Action: feed_rate=0.946 → feed_amt=445.00 g, temp_set=34.806, aeration_rate=0.92mg/L
#
# Reward Breakdown:
# Fish Value Gain:     0.6473722133629037 $
# Feed Cost:           0.52 $
# Heat Cost:           1.70 $
# Oxygenation Cost:    0.20 $
# → Net Reward:        -0.59 $
#
#
# --- Day 31 ---
# Raw-obs: biomass=4873.3 g, count=100, temp=30.84°C, DO=0.92 mg/L, UIA=0.186 mg/L
# Action: feed_rate=0.937 → feed_amt=456.76 g, temp_set=29.618, aeration_rate=0.93mg/L
#
# Reward Breakdown:
# Fish Value Gain:     0.6596981130960026 $
# Feed Cost:           0.53 $
# Heat Cost:           0.98 $
# Oxygenation Cost:    0.20 $
# → Net Reward:        -0.04 $
#
#
# --- Day 32 ---
# Raw-obs: biomass=5047.8 g, count=100, temp=30.12°C, DO=0.93 mg/L, UIA=0.184 mg/L
# Action: feed_rate=0.940 → feed_amt=474.36 g, temp_set=34.963, aeration_rate=0.93mg/L
#
# Reward Breakdown:
# Fish Value Gain:     0.686636248635621 $
# Feed Cost:           0.55 $
# Heat Cost:           1.76 $
# Oxygenation Cost:    0.20 $
# → Net Reward:        -0.59 $
#
#
# --- Day 33 ---
# Raw-obs: biomass=5229.4 g, count=100, temp=30.60°C, DO=0.93 mg/L, UIA=0.194 mg/L
# Action: feed_rate=0.930 → feed_amt=486.22 g, temp_set=30.656, aeration_rate=0.93mg/L
#
# Reward Breakdown:
# Fish Value Gain:     0.6942417592366706 $
# Feed Cost:           0.56 $
# Heat Cost:           1.34 $
# Oxygenation Cost:    0.20 $
# → Net Reward:        -0.28 $
#
#
# --- Day 34 ---
# Raw-obs: biomass=5413.1 g, count=100, temp=29.83°C, DO=0.93 mg/L, UIA=0.191 mg/L
# Action: feed_rate=0.933 → feed_amt=505.26 g, temp_set=35.810, aeration_rate=0.93mg/L
#
# Reward Breakdown:
# Fish Value Gain:     0.7345154865644979 $
# Feed Cost:           0.59 $
# Heat Cost:           1.84 $
# Oxygenation Cost:    0.20 $
# → Net Reward:        -0.59 $
#
#
# --- Day 35 ---
# Raw-obs: biomass=5607.4 g, count=100, temp=30.60°C, DO=0.93 mg/L, UIA=0.204 mg/L
# Action: feed_rate=0.917 → feed_amt=513.93 g, temp_set=29.709, aeration_rate=0.94mg/L
#
# Reward Breakdown:
# Fish Value Gain:     0.7660599938201413 $
# Feed Cost:           0.60 $
# Heat Cost:           1.24 $
# Oxygenation Cost:    0.20 $
# → Net Reward:        -0.09 $
#
#
# --- Day 36 ---
# Raw-obs: biomass=5810.1 g, count=100, temp=29.97°C, DO=0.94 mg/L, UIA=0.202 mg/L
# Action: feed_rate=0.920 → feed_amt=534.41 g, temp_set=34.347, aeration_rate=0.94mg/L
#
# Reward Breakdown:
# Fish Value Gain:     0.7974526888363546 $
# Feed Cost:           0.62 $
# Heat Cost:           1.63 $
# Oxygenation Cost:    0.20 $
# → Net Reward:        -0.34 $
#
#
# --- Day 37 ---
# Raw-obs: biomass=6021.0 g, count=100, temp=30.37°C, DO=0.94 mg/L, UIA=0.212 mg/L
# Action: feed_rate=0.904 → feed_amt=544.28 g, temp_set=30.785, aeration_rate=0.95mg/L
#
# Reward Breakdown:
# Fish Value Gain:     0.8312557527821941 $
# Feed Cost:           0.63 $
# Heat Cost:           1.32 $
# Oxygenation Cost:    0.20 $
# → Net Reward:        -0.05 $
#
#
# --- Day 38 ---
# Raw-obs: biomass=6241.0 g, count=100, temp=29.96°C, DO=0.95 mg/L, UIA=0.212 mg/L
# Action: feed_rate=0.905 → feed_amt=564.62 g, temp_set=33.503, aeration_rate=0.95mg/L
#
# Reward Breakdown:
# Fish Value Gain:     0.8687594332854301 $
# Feed Cost:           0.66 $
# Heat Cost:           1.46 $
# Oxygenation Cost:    0.20 $
# → Net Reward:        -0.10 $
#
#
# --- Day 39 ---
# Raw-obs: biomass=6470.8 g, count=100, temp=30.29°C, DO=0.95 mg/L, UIA=0.222 mg/L
# Action: feed_rate=0.886 → feed_amt=573.33 g, temp_set=30.546, aeration_rate=0.95mg/L
#
# Reward Breakdown:
# Fish Value Gain:     0.8933371350549622 $
# Feed Cost:           0.67 $
# Heat Cost:           1.04 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.25 $
#
#
# --- Day 40 ---
# Raw-obs: biomass=6707.1 g, count=100, temp=29.75°C, DO=0.95 mg/L, UIA=0.219 mg/L
# Action: feed_rate=0.892 → feed_amt=598.58 g, temp_set=33.687, aeration_rate=0.95mg/L
#
# Reward Breakdown:
# Fish Value Gain:     0.9302384917948657 $
# Feed Cost:           0.70 $
# Heat Cost:           1.33 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.08 $
#
#
# --- Day 41 ---
# Raw-obs: biomass=6953.2 g, count=100, temp=30.12°C, DO=0.95 mg/L, UIA=0.230 mg/L
# Action: feed_rate=0.867 → feed_amt=602.97 g, temp_set=30.812, aeration_rate=0.96mg/L
#
# Reward Breakdown:
# Fish Value Gain:     0.9725965112336926 $
# Feed Cost:           0.70 $
# Heat Cost:           1.46 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.07 $
#
#
# --- Day 42 ---
# Raw-obs: biomass=7210.5 g, count=100, temp=29.76°C, DO=0.96 mg/L, UIA=0.229 mg/L
# Action: feed_rate=0.872 → feed_amt=628.68 g, temp_set=32.684, aeration_rate=0.96mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.0015409583574746 $
# Feed Cost:           0.73 $
# Heat Cost:           1.40 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.14 $
#
#
# --- Day 43 ---
# Raw-obs: biomass=7475.5 g, count=100, temp=29.90°C, DO=0.96 mg/L, UIA=0.237 mg/L
# Action: feed_rate=0.851 → feed_amt=636.46 g, temp_set=31.295, aeration_rate=0.96mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.0301742643375222 $
# Feed Cost:           0.74 $
# Heat Cost:           1.40 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.19 $
#
#
# --- Day 44 ---
# Raw-obs: biomass=7748.0 g, count=100, temp=29.60°C, DO=0.96 mg/L, UIA=0.237 mg/L
# Action: feed_rate=0.853 → feed_amt=661.27 g, temp_set=32.426, aeration_rate=0.96mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.067958918334809 $
# Feed Cost:           0.77 $
# Heat Cost:           1.42 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.22 $
#
#
# --- Day 45 ---
# Raw-obs: biomass=8030.5 g, count=100, temp=29.73°C, DO=0.96 mg/L, UIA=0.245 mg/L
# Action: feed_rate=0.831 → feed_amt=667.40 g, temp_set=31.116, aeration_rate=0.97mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.1093440889008201 $
# Feed Cost:           0.77 $
# Heat Cost:           1.13 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.52 $
#
#
# --- Day 46 ---
# Raw-obs: biomass=8324.0 g, count=100, temp=29.59°C, DO=0.97 mg/L, UIA=0.246 mg/L
# Action: feed_rate=0.828 → feed_amt=689.24 g, temp_set=31.487, aeration_rate=0.97mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.1354903843233666 $
# Feed Cost:           0.80 $
# Heat Cost:           1.28 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.44 $
#
#
# --- Day 47 ---
# Raw-obs: biomass=8624.4 g, count=100, temp=29.55°C, DO=0.97 mg/L, UIA=0.252 mg/L
# Action: feed_rate=0.814 → feed_amt=701.60 g, temp_set=31.147, aeration_rate=0.97mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.1581297119336702 $
# Feed Cost:           0.81 $
# Heat Cost:           1.27 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.48 $
#
#
# --- Day 48 ---
# Raw-obs: biomass=8930.8 g, count=100, temp=29.41°C, DO=0.97 mg/L, UIA=0.254 mg/L
# Action: feed_rate=0.808 → feed_amt=721.88 g, temp_set=31.460, aeration_rate=0.97mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.1972162823221628 $
# Feed Cost:           0.84 $
# Heat Cost:           1.28 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.53 $
#
#
# --- Day 49 ---
# Raw-obs: biomass=9247.5 g, count=100, temp=29.45°C, DO=0.97 mg/L, UIA=0.259 mg/L
# Action: feed_rate=0.792 → feed_amt=732.34 g, temp_set=30.931, aeration_rate=0.97mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.2227009232828088 $
# Feed Cost:           0.85 $
# Heat Cost:           1.27 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.57 $
#
#
# --- Day 50 ---
# Raw-obs: biomass=9571.0 g, count=100, temp=29.36°C, DO=0.97 mg/L, UIA=0.262 mg/L
# Action: feed_rate=0.786 → feed_amt=752.40 g, temp_set=31.054, aeration_rate=0.97mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.254812560194684 $
# Feed Cost:           0.87 $
# Heat Cost:           1.16 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.69 $
#
#
# --- Day 51 ---
# Raw-obs: biomass=9902.9 g, count=100, temp=29.36°C, DO=0.97 mg/L, UIA=0.267 mg/L
# Action: feed_rate=0.771 → feed_amt=763.70 g, temp_set=30.706, aeration_rate=0.98mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.2644250808341435 $
# Feed Cost:           0.88 $
# Heat Cost:           1.01 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.82 $
#
#
# --- Day 52 ---
# Raw-obs: biomass=10237.4 g, count=100, temp=29.22°C, DO=0.98 mg/L, UIA=0.269 mg/L
# Action: feed_rate=0.768 → feed_amt=786.34 g, temp_set=30.939, aeration_rate=0.98mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.2977413419546242 $
# Feed Cost:           0.91 $
# Heat Cost:           1.15 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.76 $
#
#
# --- Day 53 ---
# Raw-obs: biomass=10580.8 g, count=100, temp=29.25°C, DO=0.98 mg/L, UIA=0.275 mg/L
# Action: feed_rate=0.751 → feed_amt=794.44 g, temp_set=30.518, aeration_rate=0.98mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.2899126386078212 $
# Feed Cost:           0.92 $
# Heat Cost:           0.99 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.85 $
#
#
# --- Day 54 ---
# Raw-obs: biomass=10922.0 g, count=100, temp=29.06°C, DO=0.98 mg/L, UIA=0.274 mg/L
# Action: feed_rate=0.752 → feed_amt=821.33 g, temp_set=30.875, aeration_rate=0.98mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.3254148386368287 $
# Feed Cost:           0.95 $
# Heat Cost:           1.26 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.69 $
#
#
# --- Day 55 ---
# Raw-obs: biomass=11272.6 g, count=100, temp=29.10°C, DO=0.98 mg/L, UIA=0.281 mg/L
# Action: feed_rate=0.730 → feed_amt=822.55 g, temp_set=30.511, aeration_rate=0.98mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.324027377627972 $
# Feed Cost:           0.95 $
# Heat Cost:           1.02 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.87 $
#
#
# --- Day 56 ---
# Raw-obs: biomass=11622.9 g, count=100, temp=28.97°C, DO=0.98 mg/L, UIA=0.281 mg/L
# Action: feed_rate=0.733 → feed_amt=851.67 g, temp_set=30.723, aeration_rate=0.98mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.356808268640882 $
# Feed Cost:           0.98 $
# Heat Cost:           1.23 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.75 $
#
#
# --- Day 57 ---
# Raw-obs: biomass=11981.9 g, count=100, temp=29.01°C, DO=0.98 mg/L, UIA=0.288 mg/L
# Action: feed_rate=0.709 → feed_amt=849.63 g, temp_set=30.464, aeration_rate=0.98mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.3599190594812927 $
# Feed Cost:           0.98 $
# Heat Cost:           1.18 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.79 $
#
#
# --- Day 58 ---
# Raw-obs: biomass=12341.6 g, count=100, temp=28.92°C, DO=0.98 mg/L, UIA=0.287 mg/L
# Action: feed_rate=0.712 → feed_amt=878.25 g, temp_set=30.594, aeration_rate=0.98mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.3883229875501155 $
# Feed Cost:           1.01 $
# Heat Cost:           1.01 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.95 $
#
#
# --- Day 59 ---
# Raw-obs: biomass=12708.9 g, count=100, temp=28.93°C, DO=0.98 mg/L, UIA=0.293 mg/L
# Action: feed_rate=0.693 → feed_amt=880.18 g, temp_set=30.435, aeration_rate=0.98mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.3847065390021773 $
# Feed Cost:           1.01 $
# Heat Cost:           1.14 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.85 $
#
#
# --- Day 60 ---
# Raw-obs: biomass=13075.2 g, count=100, temp=28.85°C, DO=0.98 mg/L, UIA=0.294 mg/L
# Action: feed_rate=0.693 → feed_amt=905.70 g, temp_set=30.538, aeration_rate=0.98mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.3976677067282948 $
# Feed Cost:           1.04 $
# Heat Cost:           1.13 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.85 $
#
#
# --- Day 61 ---
# Raw-obs: biomass=13445.0 g, count=100, temp=28.81°C, DO=0.98 mg/L, UIA=0.298 mg/L
# Action: feed_rate=0.684 → feed_amt=919.87 g, temp_set=30.470, aeration_rate=0.98mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.4207831874047234 $
# Feed Cost:           1.06 $
# Heat Cost:           1.00 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.98 $
#
#
# --- Day 62 ---
# Raw-obs: biomass=13820.9 g, count=100, temp=28.82°C, DO=0.98 mg/L, UIA=0.303 mg/L
# Action: feed_rate=0.676 → feed_amt=934.72 g, temp_set=30.359, aeration_rate=0.98mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.4319193908952554 $
# Feed Cost:           1.08 $
# Heat Cost:           1.03 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.97 $
#
#
# --- Day 63 ---
# Raw-obs: biomass=14199.7 g, count=100, temp=28.80°C, DO=0.98 mg/L, UIA=0.306 mg/L
# Action: feed_rate=0.670 → feed_amt=952.09 g, temp_set=30.297, aeration_rate=0.98mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.434743098619361 $
# Feed Cost:           1.09 $
# Heat Cost:           0.78 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        1.14 $
#
#
# --- Day 64 ---
# Raw-obs: biomass=14579.2 g, count=100, temp=28.74°C, DO=0.98 mg/L, UIA=0.309 mg/L
# Action: feed_rate=0.665 → feed_amt=970.14 g, temp_set=30.261, aeration_rate=0.98mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.4034129636746406 $
# Feed Cost:           1.11 $
# Heat Cost:           1.02 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.88 $
#
#
# --- Day 65 ---
# Raw-obs: biomass=14950.5 g, count=100, temp=28.59°C, DO=0.98 mg/L, UIA=0.311 mg/L
# Action: feed_rate=0.665 → feed_amt=994.56 g, temp_set=30.333, aeration_rate=0.98mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.4582714506276422 $
# Feed Cost:           1.14 $
# Heat Cost:           1.05 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.94 $
#
#
# --- Day 66 ---
# Raw-obs: biomass=15336.3 g, count=100, temp=28.70°C, DO=0.98 mg/L, UIA=0.318 mg/L
# Action: feed_rate=0.650 → feed_amt=997.08 g, temp_set=30.065, aeration_rate=0.98mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.4775086500214847 $
# Feed Cost:           1.15 $
# Heat Cost:           0.87 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        1.11 $
#
#
# --- Day 67 ---
# Raw-obs: biomass=15727.2 g, count=100, temp=28.72°C, DO=0.98 mg/L, UIA=0.320 mg/L
# Action: feed_rate=0.646 → feed_amt=1015.55 g, temp_set=29.992, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.457411042796236 $
# Feed Cost:           1.17 $
# Heat Cost:           0.68 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        1.19 $
#
#
# --- Day 68 ---
# Raw-obs: biomass=16112.7 g, count=100, temp=28.60°C, DO=0.99 mg/L, UIA=0.322 mg/L
# Action: feed_rate=0.644 → feed_amt=1038.32 g, temp_set=30.015, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.4570662665774758 $
# Feed Cost:           1.19 $
# Heat Cost:           0.92 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.99 $
#
#
# --- Day 69 ---
# Raw-obs: biomass=16498.2 g, count=100, temp=28.55°C, DO=0.99 mg/L, UIA=0.326 mg/L
# Action: feed_rate=0.638 → feed_amt=1053.00 g, temp_set=29.939, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.5093353061242343 $
# Feed Cost:           1.21 $
# Heat Cost:           0.84 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        1.14 $
#
#
# --- Day 70 ---
# Raw-obs: biomass=16897.5 g, count=100, temp=28.66°C, DO=0.99 mg/L, UIA=0.332 mg/L
# Action: feed_rate=0.626 → feed_amt=1057.11 g, temp_set=29.708, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.490023391419052 $
# Feed Cost:           1.21 $
# Heat Cost:           1.00 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.98 $
#
#
# --- Day 71 ---
# Raw-obs: biomass=17291.7 g, count=100, temp=28.57°C, DO=0.99 mg/L, UIA=0.332 mg/L
# Action: feed_rate=0.627 → feed_amt=1083.91 g, temp_set=29.766, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.5049424589364788 $
# Feed Cost:           1.24 $
# Heat Cost:           0.69 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        1.22 $
#
#
# --- Day 72 ---
# Raw-obs: biomass=17689.8 g, count=100, temp=28.56°C, DO=0.99 mg/L, UIA=0.337 mg/L
# Action: feed_rate=0.618 → feed_amt=1092.80 g, temp_set=29.633, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.452593998022328 $
# Feed Cost:           1.25 $
# Heat Cost:           0.79 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        1.03 $
#
#
# --- Day 73 ---
# Raw-obs: biomass=18074.1 g, count=100, temp=28.40°C, DO=0.99 mg/L, UIA=0.337 mg/L
# Action: feed_rate=0.622 → feed_amt=1124.29 g, temp_set=29.754, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.4761230622587715 $
# Feed Cost:           1.29 $
# Heat Cost:           0.71 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        1.10 $
#
#
# --- Day 74 ---
# Raw-obs: biomass=18464.6 g, count=100, temp=28.41°C, DO=0.99 mg/L, UIA=0.343 mg/L
# Action: feed_rate=0.610 → feed_amt=1127.01 g, temp_set=29.584, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.4487999750353655 $
# Feed Cost:           1.29 $
# Heat Cost:           0.83 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.96 $
#
#
# --- Day 75 ---
# Raw-obs: biomass=18847.9 g, count=100, temp=28.33°C, DO=0.99 mg/L, UIA=0.343 mg/L
# Action: feed_rate=0.612 → feed_amt=1153.35 g, temp_set=29.632, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.4979148325363476 $
# Feed Cost:           1.32 $
# Heat Cost:           0.81 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        1.04 $
#
#
# --- Day 76 ---
# Raw-obs: biomass=19244.2 g, count=100, temp=28.41°C, DO=0.99 mg/L, UIA=0.349 mg/L
# Action: feed_rate=0.598 → feed_amt=1150.70 g, temp_set=29.408, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.46309390491274 $
# Feed Cost:           1.31 $
# Heat Cost:           0.63 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        1.11 $
#
#
# --- Day 77 ---
# Raw-obs: biomass=19631.2 g, count=100, temp=28.32°C, DO=0.99 mg/L, UIA=0.348 mg/L
# Action: feed_rate=0.602 → feed_amt=1181.32 g, temp_set=29.496, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.4865120092266735 $
# Feed Cost:           1.35 $
# Heat Cost:           0.74 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        1.04 $
#
#
# --- Day 78 ---
# Raw-obs: biomass=20024.5 g, count=100, temp=28.33°C, DO=0.99 mg/L, UIA=0.354 mg/L
# Action: feed_rate=0.590 → feed_amt=1181.65 g, temp_set=29.327, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.469290263755359 $
# Feed Cost:           1.35 $
# Heat Cost:           0.75 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        1.00 $
#
#
# --- Day 79 ---
# Raw-obs: biomass=20413.2 g, count=100, temp=28.29°C, DO=0.99 mg/L, UIA=0.354 mg/L
# Action: feed_rate=0.590 → feed_amt=1205.14 g, temp_set=29.347, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.51903599918737 $
# Feed Cost:           1.38 $
# Heat Cost:           0.67 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        1.14 $
#
#
# --- Day 80 ---
# Raw-obs: biomass=20815.0 g, count=100, temp=28.37°C, DO=0.99 mg/L, UIA=0.360 mg/L
# Action: feed_rate=0.577 → feed_amt=1200.44 g, temp_set=29.139, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.480946517811067 $
# Feed Cost:           1.37 $
# Heat Cost:           0.42 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        1.26 $
#
#
# --- Day 81 ---
# Raw-obs: biomass=21206.8 g, count=100, temp=28.29°C, DO=0.99 mg/L, UIA=0.359 mg/L
# Action: feed_rate=0.581 → feed_amt=1231.63 g, temp_set=29.213, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.5034196609098336 $
# Feed Cost:           1.41 $
# Heat Cost:           0.55 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        1.17 $
#
#
# --- Day 82 ---
# Raw-obs: biomass=21604.6 g, count=100, temp=28.30°C, DO=0.99 mg/L, UIA=0.364 mg/L
# Action: feed_rate=0.570 → feed_amt=1230.79 g, temp_set=29.072, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.445197245360814 $
# Feed Cost:           1.40 $
# Heat Cost:           0.52 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        1.08 $
#
#
# --- Day 83 ---
# Raw-obs: biomass=21986.9 g, count=100, temp=28.18°C, DO=0.99 mg/L, UIA=0.363 mg/L
# Action: feed_rate=0.575 → feed_amt=1264.64 g, temp_set=29.173, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.4274453123071722 $
# Feed Cost:           1.44 $
# Heat Cost:           0.75 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.84 $
#
#
# --- Day 84 ---
# Raw-obs: biomass=22364.5 g, count=100, temp=28.10°C, DO=0.99 mg/L, UIA=0.367 mg/L
# Action: feed_rate=0.569 → feed_amt=1271.86 g, temp_set=29.106, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.457713277602657 $
# Feed Cost:           1.45 $
# Heat Cost:           0.59 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        1.01 $
#
#
# --- Day 85 ---
# Raw-obs: biomass=22750.1 g, count=100, temp=28.16°C, DO=0.99 mg/L, UIA=0.370 mg/L
# Action: feed_rate=0.561 → feed_amt=1275.54 g, temp_set=28.999, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.4713260084308977 $
# Feed Cost:           1.45 $
# Heat Cost:           0.71 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.94 $
#
#
# --- Day 86 ---
# Raw-obs: biomass=23139.4 g, count=100, temp=28.19°C, DO=0.99 mg/L, UIA=0.372 mg/L
# Action: feed_rate=0.557 → feed_amt=1288.35 g, temp_set=28.930, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.457943048780122 $
# Feed Cost:           1.47 $
# Heat Cost:           0.53 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        1.03 $
#
#
# --- Day 87 ---
# Raw-obs: biomass=23525.1 g, count=100, temp=28.16°C, DO=0.99 mg/L, UIA=0.374 mg/L
# Action: feed_rate=0.555 → feed_amt=1306.05 g, temp_set=28.889, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.441962441519755 $
# Feed Cost:           1.49 $
# Heat Cost:           0.40 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        1.09 $
#
#
# --- Day 88 ---
# Raw-obs: biomass=23906.6 g, count=100, temp=28.11°C, DO=0.99 mg/L, UIA=0.376 mg/L
# Action: feed_rate=0.553 → feed_amt=1322.44 g, temp_set=28.833, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.3944703846395974 $
# Feed Cost:           1.50 $
# Heat Cost:           0.40 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.97 $
#
#
# --- Day 89 ---
# Raw-obs: biomass=24275.5 g, count=100, temp=28.00°C, DO=0.99 mg/L, UIA=0.377 mg/L
# Action: feed_rate=0.554 → feed_amt=1344.96 g, temp_set=28.849, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.4157052470847082 $
# Feed Cost:           1.53 $
# Heat Cost:           0.44 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.96 $
#
#
# --- Day 90 ---
# Raw-obs: biomass=24650.0 g, count=100, temp=28.02°C, DO=0.99 mg/L, UIA=0.381 mg/L
# Action: feed_rate=0.548 → feed_amt=1351.04 g, temp_set=28.692, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.430805882177651 $
# Feed Cost:           1.54 $
# Heat Cost:           0.59 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.88 $
#
#
# --- Day 91 ---
# Raw-obs: biomass=25028.5 g, count=100, temp=28.06°C, DO=0.99 mg/L, UIA=0.384 mg/L
# Action: feed_rate=0.544 → feed_amt=1362.27 g, temp_set=28.601, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.3916407028365956 $
# Feed Cost:           1.55 $
# Heat Cost:           0.24 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        1.05 $
#
#
# --- Day 92 ---
# Raw-obs: biomass=25396.7 g, count=100, temp=27.98°C, DO=0.99 mg/L, UIA=0.385 mg/L
# Action: feed_rate=0.545 → feed_amt=1383.49 g, temp_set=28.603, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.340945397276835 $
# Feed Cost:           1.57 $
# Heat Cost:           0.56 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.69 $
#
#
# --- Day 93 ---
# Raw-obs: biomass=25751.4 g, count=100, temp=27.87°C, DO=0.99 mg/L, UIA=0.386 mg/L
# Action: feed_rate=0.546 → feed_amt=1405.14 g, temp_set=28.613, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.3763253345325082 $
# Feed Cost:           1.60 $
# Heat Cost:           0.54 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.75 $
#
#
# --- Day 94 ---
# Raw-obs: biomass=26115.5 g, count=100, temp=27.92°C, DO=0.99 mg/L, UIA=0.391 mg/L
# Action: feed_rate=0.539 → feed_amt=1406.46 g, temp_set=28.436, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.3142696044638267 $
# Feed Cost:           1.60 $
# Heat Cost:           0.38 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.75 $
#
#
# --- Day 95 ---
# Raw-obs: biomass=26463.2 g, count=100, temp=27.82°C, DO=0.99 mg/L, UIA=0.390 mg/L
# Action: feed_rate=0.542 → feed_amt=1434.20 g, temp_set=28.513, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.3245317720107945 $
# Feed Cost:           1.63 $
# Heat Cost:           0.50 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.65 $
#
#
# --- Day 96 ---
# Raw-obs: biomass=26813.6 g, count=100, temp=27.81°C, DO=0.99 mg/L, UIA=0.394 mg/L
# Action: feed_rate=0.537 → feed_amt=1439.89 g, temp_set=28.386, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.2837765906401675 $
# Feed Cost:           1.63 $
# Heat Cost:           0.33 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.69 $
#
#
# --- Day 97 ---
# Raw-obs: biomass=27153.2 g, count=100, temp=27.74°C, DO=0.99 mg/L, UIA=0.394 mg/L
# Action: feed_rate=0.538 → feed_amt=1460.98 g, temp_set=28.406, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.2526929311178328 $
# Feed Cost:           1.66 $
# Heat Cost:           0.33 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.61 $
#
#
# --- Day 98 ---
# Raw-obs: biomass=27484.6 g, count=100, temp=27.67°C, DO=0.99 mg/L, UIA=0.396 mg/L
# Action: feed_rate=0.538 → feed_amt=1477.34 g, temp_set=28.377, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.2800812942274917 $
# Feed Cost:           1.68 $
# Heat Cost:           0.33 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.65 $
#
#
# --- Day 99 ---
# Raw-obs: biomass=27823.3 g, count=100, temp=27.72°C, DO=0.99 mg/L, UIA=0.400 mg/L
# Action: feed_rate=0.532 → feed_amt=1479.56 g, temp_set=28.240, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.300836786416095 $
# Feed Cost:           1.68 $
# Heat Cost:           0.33 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.68 $
#
#
# --- Day 100 ---
# Raw-obs: biomass=28167.4 g, count=100, temp=27.77°C, DO=0.99 mg/L, UIA=0.402 mg/L
# Action: feed_rate=0.528 → feed_amt=1487.20 g, temp_set=28.167, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.299793919395799 $
# Feed Cost:           1.69 $
# Heat Cost:           0.37 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.64 $
#
#
# --- Day 101 ---
# Raw-obs: biomass=28511.3 g, count=100, temp=27.77°C, DO=0.99 mg/L, UIA=0.404 mg/L
# Action: feed_rate=0.526 → feed_amt=1499.83 g, temp_set=28.129, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.2963797995688724 $
# Feed Cost:           1.70 $
# Heat Cost:           0.40 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.60 $
#
#
# --- Day 102 ---
# Raw-obs: biomass=28854.2 g, count=100, temp=27.77°C, DO=0.99 mg/L, UIA=0.406 mg/L
# Action: feed_rate=0.524 → feed_amt=1511.51 g, temp_set=28.080, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.2950807582975465 $
# Feed Cost:           1.71 $
# Heat Cost:           0.34 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.64 $
#
#
# --- Day 103 ---
# Raw-obs: biomass=29196.9 g, count=100, temp=27.77°C, DO=0.99 mg/L, UIA=0.408 mg/L
# Action: feed_rate=0.521 → feed_amt=1522.52 g, temp_set=28.029, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.2709908445175546 $
# Feed Cost:           1.72 $
# Heat Cost:           0.03 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.81 $
#
#
# --- Day 104 ---
# Raw-obs: biomass=29533.1 g, count=100, temp=27.72°C, DO=0.99 mg/L, UIA=0.409 mg/L
# Action: feed_rate=0.521 → feed_amt=1538.44 g, temp_set=28.002, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.3099535613141324 $
# Feed Cost:           1.74 $
# Heat Cost:           0.17 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.76 $
#
#
# --- Day 105 ---
# Raw-obs: biomass=29879.6 g, count=100, temp=27.79°C, DO=0.99 mg/L, UIA=0.413 mg/L
# Action: feed_rate=0.515 → feed_amt=1539.60 g, temp_set=27.907, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.2794648957042067 $
# Feed Cost:           1.74 $
# Heat Cost:           0.03 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.81 $
#
#
# --- Day 106 ---
# Raw-obs: biomass=30218.1 g, count=100, temp=27.75°C, DO=0.99 mg/L, UIA=0.413 mg/L
# Action: feed_rate=0.516 → feed_amt=1558.24 g, temp_set=27.903, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.2495144518507195 $
# Feed Cost:           1.76 $
# Heat Cost:           0.19 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.61 $
#
#
# --- Day 107 ---
# Raw-obs: biomass=30548.7 g, count=100, temp=27.69°C, DO=0.99 mg/L, UIA=0.415 mg/L
# Action: feed_rate=0.515 → feed_amt=1574.18 g, temp_set=27.872, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.2373881329472876 $
# Feed Cost:           1.78 $
# Heat Cost:           0.06 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.67 $
#
#
# --- Day 108 ---
# Raw-obs: biomass=30876.0 g, count=100, temp=27.66°C, DO=0.99 mg/L, UIA=0.417 mg/L
# Action: feed_rate=0.513 → feed_amt=1585.47 g, temp_set=27.826, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.2389268565481024 $
# Feed Cost:           1.79 $
# Heat Cost:           0.22 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.54 $
#
#
# --- Day 109 ---
# Raw-obs: biomass=31203.8 g, count=100, temp=27.67°C, DO=0.99 mg/L, UIA=0.419 mg/L
# Action: feed_rate=0.511 → feed_amt=1594.41 g, temp_set=27.776, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.245714042627432 $
# Feed Cost:           1.80 $
# Heat Cost:           0.01 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.70 $
#
#
# --- Day 110 ---
# Raw-obs: biomass=31533.4 g, count=100, temp=27.69°C, DO=0.99 mg/L, UIA=0.421 mg/L
# Action: feed_rate=0.509 → feed_amt=1603.51 g, temp_set=27.734, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.1869985829705214 $
# Feed Cost:           1.81 $
# Heat Cost:           0.08 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.52 $
#
#
# --- Day 111 ---
# Raw-obs: biomass=31847.4 g, count=100, temp=27.59°C, DO=0.99 mg/L, UIA=0.420 mg/L
# Action: feed_rate=0.511 → feed_amt=1626.19 g, temp_set=27.740, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.1678362433177916 $
# Feed Cost:           1.84 $
# Heat Cost:           0.10 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.44 $
#
#
# --- Day 112 ---
# Raw-obs: biomass=32156.3 g, count=100, temp=27.54°C, DO=0.99 mg/L, UIA=0.423 mg/L
# Action: feed_rate=0.509 → feed_amt=1638.02 g, temp_set=27.690, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.17869105499072 $
# Feed Cost:           1.85 $
# Heat Cost:           0.17 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.40 $
#
#
# --- Day 113 ---
# Raw-obs: biomass=32468.1 g, count=100, temp=27.56°C, DO=0.99 mg/L, UIA=0.425 mg/L
# Action: feed_rate=0.506 → feed_amt=1643.18 g, temp_set=27.636, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.1864804294195495 $
# Feed Cost:           1.86 $
# Heat Cost:           0.12 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.45 $
#
#
# --- Day 114 ---
# Raw-obs: biomass=32782.0 g, count=100, temp=27.59°C, DO=0.99 mg/L, UIA=0.427 mg/L
# Action: feed_rate=0.504 → feed_amt=1651.81 g, temp_set=27.602, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.1700468790562824 $
# Feed Cost:           1.87 $
# Heat Cost:           0.07 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.44 $
#
#
# --- Day 115 ---
# Raw-obs: biomass=33091.6 g, count=100, temp=27.56°C, DO=0.99 mg/L, UIA=0.428 mg/L
# Action: feed_rate=0.503 → feed_amt=1665.10 g, temp_set=27.578, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.2133370574821944 $
# Feed Cost:           1.88 $
# Heat Cost:           0.10 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.50 $
#
#
# --- Day 116 ---
# Raw-obs: biomass=33412.6 g, count=100, temp=27.64°C, DO=0.99 mg/L, UIA=0.432 mg/L
# Action: feed_rate=0.498 → feed_amt=1664.03 g, temp_set=27.515, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.1851743173370082 $
# Feed Cost:           1.88 $
# Heat Cost:           0.14 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.41 $
#
#
# --- Day 117 ---
# Raw-obs: biomass=33726.1 g, count=100, temp=27.61°C, DO=0.99 mg/L, UIA=0.432 mg/L
# Action: feed_rate=0.499 → feed_amt=1681.25 g, temp_set=27.512, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.1958356923386164 $
# Feed Cost:           1.90 $
# Heat Cost:           0.00 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.52 $
#
#
# --- Day 118 ---
# Raw-obs: biomass=34042.5 g, count=100, temp=27.63°C, DO=0.99 mg/L, UIA=0.435 mg/L
# Action: feed_rate=0.496 → feed_amt=1686.81 g, temp_set=27.457, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.1914401435198747 $
# Feed Cost:           1.91 $
# Heat Cost:           0.00 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.51 $
#
#
# --- Day 119 ---
# Raw-obs: biomass=34357.7 g, count=100, temp=27.63°C, DO=0.99 mg/L, UIA=0.436 mg/L
# Action: feed_rate=0.494 → feed_amt=1697.01 g, temp_set=27.426, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.2185699278911295 $
# Feed Cost:           1.92 $
# Heat Cost:           0.00 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.55 $
#
#
# --- Day 120 ---
# Raw-obs: biomass=34680.0 g, count=100, temp=27.69°C, DO=0.99 mg/L, UIA=0.440 mg/L
# Action: feed_rate=0.490 → feed_amt=1699.01 g, temp_set=27.368, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.177961495261222 $
# Feed Cost:           1.92 $
# Heat Cost:           0.00 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.47 $
#
#
# --- Day 121 ---
# Raw-obs: biomass=34991.7 g, count=100, temp=27.63°C, DO=0.99 mg/L, UIA=0.439 mg/L
# Action: feed_rate=0.491 → feed_amt=1718.95 g, temp_set=27.370, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.223869242436793 $
# Feed Cost:           1.94 $
# Heat Cost:           0.00 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.54 $
#
#
# --- Day 122 ---
# Raw-obs: biomass=35315.4 g, count=100, temp=27.71°C, DO=0.99 mg/L, UIA=0.444 mg/L
# Action: feed_rate=0.485 → feed_amt=1714.26 g, temp_set=27.284, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.1697120882450152 $
# Feed Cost:           1.94 $
# Heat Cost:           0.00 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.44 $
#
#
# --- Day 123 ---
# Raw-obs: biomass=35624.9 g, count=100, temp=27.64°C, DO=0.99 mg/L, UIA=0.442 mg/L
# Action: feed_rate=0.488 → feed_amt=1738.43 g, temp_set=27.306, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.1538190617240194 $
# Feed Cost:           1.96 $
# Heat Cost:           0.09 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.31 $
#
#
# --- Day 124 ---
# Raw-obs: biomass=35930.1 g, count=100, temp=27.59°C, DO=0.99 mg/L, UIA=0.444 mg/L
# Action: feed_rate=0.487 → feed_amt=1748.70 g, temp_set=27.257, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.1749337492989278 $
# Feed Cost:           1.98 $
# Heat Cost:           0.00 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.41 $
#
#
# --- Day 125 ---
# Raw-obs: biomass=36240.9 g, count=100, temp=27.64°C, DO=0.99 mg/L, UIA=0.447 mg/L
# Action: feed_rate=0.483 → feed_amt=1750.34 g, temp_set=27.203, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.1755243622508285 $
# Feed Cost:           1.98 $
# Heat Cost:           0.00 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.41 $
#
#
# --- Day 126 ---
# Raw-obs: biomass=36551.9 g, count=100, temp=27.66°C, DO=0.99 mg/L, UIA=0.449 mg/L
# Action: feed_rate=0.481 → feed_amt=1759.14 g, temp_set=27.179, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.1977794907226564 $
# Feed Cost:           1.99 $
# Heat Cost:           0.00 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.44 $
#
#
# --- Day 127 ---
# Raw-obs: biomass=36868.8 g, count=100, temp=27.71°C, DO=0.99 mg/L, UIA=0.451 mg/L
# Action: feed_rate=0.478 → feed_amt=1761.18 g, temp_set=27.129, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.2554846905831454 $
# Feed Cost:           1.99 $
# Heat Cost:           0.00 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.56 $
#
#
# --- Day 128 ---
# Raw-obs: biomass=37200.9 g, count=100, temp=27.85°C, DO=0.99 mg/L, UIA=0.456 mg/L
# Action: feed_rate=0.471 → feed_amt=1750.62 g, temp_set=27.003, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.249302244268254 $
# Feed Cost:           1.98 $
# Heat Cost:           0.00 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.56 $
#
#
# --- Day 129 ---
# Raw-obs: biomass=37531.4 g, count=100, temp=27.89°C, DO=0.99 mg/L, UIA=0.456 mg/L
# Action: feed_rate=0.470 → feed_amt=1762.85 g, temp_set=26.989, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.250310131750419 $
# Feed Cost:           1.99 $
# Heat Cost:           0.00 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.55 $
#
#
# --- Day 130 ---
# Raw-obs: biomass=37862.2 g, count=100, temp=27.89°C, DO=0.99 mg/L, UIA=0.458 mg/L
# Action: feed_rate=0.468 → feed_amt=1770.56 g, temp_set=26.943, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.2889072893978133 $
# Feed Cost:           2.00 $
# Heat Cost:           0.00 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.62 $
#
#
# --- Day 131 ---
# Raw-obs: biomass=38203.2 g, count=100, temp=27.99°C, DO=0.99 mg/L, UIA=0.462 mg/L
# Action: feed_rate=0.462 → feed_amt=1763.82 g, temp_set=26.804, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.2719865045495051 $
# Feed Cost:           1.99 $
# Heat Cost:           0.00 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.59 $
#
#
# --- Day 132 ---
# Raw-obs: biomass=38539.7 g, count=100, temp=28.00°C, DO=0.99 mg/L, UIA=0.462 mg/L
# Action: feed_rate=0.461 → feed_amt=1777.93 g, temp_set=26.796, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.2945325822495275 $
# Feed Cost:           2.01 $
# Heat Cost:           0.00 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.62 $
#
#
# --- Day 133 ---
# Raw-obs: biomass=38882.2 g, count=100, temp=28.05°C, DO=0.99 mg/L, UIA=0.465 mg/L
# Action: feed_rate=0.458 → feed_amt=1779.09 g, temp_set=26.720, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.3043943551560189 $
# Feed Cost:           2.01 $
# Heat Cost:           0.00 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.64 $
#
#
# --- Day 134 ---
# Raw-obs: biomass=39227.2 g, count=100, temp=28.11°C, DO=0.99 mg/L, UIA=0.468 mg/L
# Action: feed_rate=0.455 → feed_amt=1785.89 g, temp_set=26.683, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.2786373468982444 $
# Feed Cost:           2.02 $
# Heat Cost:           0.00 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.58 $
#
#
# --- Day 135 ---
# ...
# Reward Breakdown:
# Fish Value Gain:     1.3251621954617263 $
# Feed Cost:           2.04 $
# Heat Cost:           0.00 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.65 $
#
#
# --- Day 137 ---
# Raw-obs: biomass=40255.8 g, count=100, temp=28.22°C, DO=0.99 mg/L, UIA=0.475 mg/L
# Action: feed_rate=0.449 → feed_amt=1805.74 g, temp_set=26.533, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.3287050730787713 $
# Feed Cost:           2.04 $
# Heat Cost:           0.00 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.66 $
#
#
# --- Day 138 ---
# Raw-obs: biomass=40607.4 g, count=100, temp=28.28°C, DO=0.99 mg/L, UIA=0.478 mg/L
# Action: feed_rate=0.447 → feed_amt=1814.11 g, temp_set=26.479, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.3190584209971659 $
# Feed Cost:           2.05 $
# Heat Cost:           0.00 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.63 $
#
#
# --- Day 139 ---
# Raw-obs: biomass=40956.3 g, count=100, temp=28.28°C, DO=0.99 mg/L, UIA=0.480 mg/L
# Action: feed_rate=0.445 → feed_amt=1824.06 g, temp_set=26.441, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.3439266393909248 $
# Feed Cost:           2.06 $
# Heat Cost:           0.00 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.67 $
#
#
# --- Day 140 ---
# Raw-obs: biomass=41311.8 g, count=100, temp=28.36°C, DO=0.99 mg/L, UIA=0.484 mg/L
# Action: feed_rate=0.442 → feed_amt=1827.77 g, temp_set=26.350, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.3803417983066428 $
# Feed Cost:           2.07 $
# Heat Cost:           0.00 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.74 $
#
#
# --- Day 141 ---
# Raw-obs: biomass=41677.0 g, count=100, temp=28.51°C, DO=0.99 mg/L, UIA=0.489 mg/L
# Action: feed_rate=0.439 → feed_amt=1830.71 g, temp_set=26.206, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.3745199838892355 $
# Feed Cost:           2.07 $
# Heat Cost:           0.00 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.73 $
#
#
# --- Day 142 ---
# Raw-obs: biomass=42040.6 g, count=100, temp=28.55°C, DO=0.99 mg/L, UIA=0.492 mg/L
# Action: feed_rate=0.438 → feed_amt=1840.57 g, temp_set=26.125, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.3863645017771613 $
# Feed Cost:           2.08 $
# Heat Cost:           0.00 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.74 $
#
#
# --- Day 143 ---
# Raw-obs: biomass=42407.4 g, count=100, temp=28.62°C, DO=0.99 mg/L, UIA=0.495 mg/L
# Action: feed_rate=0.436 → feed_amt=1848.37 g, temp_set=26.005, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.3844910868463882 $
# Feed Cost:           2.09 $
# Heat Cost:           0.00 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.73 $
#
#
# --- Day 144 ---
# Raw-obs: biomass=42773.7 g, count=100, temp=28.66°C, DO=0.99 mg/L, UIA=0.498 mg/L
# Action: feed_rate=0.434 → feed_amt=1857.65 g, temp_set=25.914, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.385330806230733 $
# Feed Cost:           2.10 $
# Heat Cost:           0.00 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.72 $
#
#
# --- Day 145 ---
# Raw-obs: biomass=43140.2 g, count=100, temp=28.70°C, DO=0.99 mg/L, UIA=0.502 mg/L
# Action: feed_rate=0.433 → feed_amt=1866.58 g, temp_set=25.822, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.3606265026076434 $
# Feed Cost:           2.11 $
# Heat Cost:           0.00 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.66 $
#
#
# --- Day 146 ---
# Raw-obs: biomass=43500.1 g, count=100, temp=28.67°C, DO=0.99 mg/L, UIA=0.502 mg/L
# Action: feed_rate=0.432 → feed_amt=1878.29 g, temp_set=25.813, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.3585558554280641 $
# Feed Cost:           2.12 $
# Heat Cost:           0.00 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.65 $
#
#
# --- Day 147 ---
# Raw-obs: biomass=43859.5 g, count=100, temp=28.68°C, DO=0.99 mg/L, UIA=0.505 mg/L
# Action: feed_rate=0.430 → feed_amt=1887.94 g, temp_set=25.754, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.3138600551050463 $
# Feed Cost:           2.13 $
# Heat Cost:           0.00 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.55 $
#
#
# --- Day 148 ---
# Raw-obs: biomass=44207.1 g, count=100, temp=28.58°C, DO=0.99 mg/L, UIA=0.504 mg/L
# Action: feed_rate=0.430 → feed_amt=1901.98 g, temp_set=25.815, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.323874187219229 $
# Feed Cost:           2.15 $
# Heat Cost:           0.00 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.55 $
#
#
# --- Day 149 ---
# Raw-obs: biomass=44557.3 g, count=100, temp=28.61°C, DO=0.99 mg/L, UIA=0.506 mg/L
# Action: feed_rate=0.429 → feed_amt=1910.51 g, temp_set=25.738, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.3385978230934257 $
# Feed Cost:           2.16 $
# Heat Cost:           0.00 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.58 $
#
#
# --- Day 150 ---
# Raw-obs: biomass=44911.5 g, count=100, temp=28.70°C, DO=0.99 mg/L, UIA=0.511 mg/L
# Action: feed_rate=0.427 → feed_amt=1917.01 g, temp_set=25.616, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.3342240183463345 $
# Feed Cost:           2.16 $
# Heat Cost:           0.00 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.56 $
#
#
# --- Day 151 ---
# Raw-obs: biomass=45264.4 g, count=100, temp=28.74°C, DO=0.99 mg/L, UIA=0.514 mg/L
# Action: feed_rate=0.425 → feed_amt=1923.68 g, temp_set=25.540, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.332782709397317 $
# Feed Cost:           2.17 $
# Heat Cost:           0.00 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.55 $
#
#
# --- Day 152 ---
# Raw-obs: biomass=45617.0 g, count=100, temp=28.79°C, DO=0.99 mg/L, UIA=0.516 mg/L
# Action: feed_rate=0.422 → feed_amt=1923.21 g, temp_set=25.463, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.3242045246473708 $
# Feed Cost:           2.17 $
# Heat Cost:           0.00 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.53 $
#
#
# --- Day 153 ---
# Raw-obs: biomass=45967.3 g, count=100, temp=28.84°C, DO=0.99 mg/L, UIA=0.518 mg/L
# Action: feed_rate=0.419 → feed_amt=1927.24 g, temp_set=25.410, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.3088996473208727 $
# Feed Cost:           2.17 $
# Heat Cost:           0.00 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.50 $
#
#
# --- Day 154 ---
# Raw-obs: biomass=46313.6 g, count=100, temp=28.84°C, DO=0.99 mg/L, UIA=0.519 mg/L
# Action: feed_rate=0.418 → feed_amt=1935.85 g, temp_set=25.388, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.2907468935441255 $
# Feed Cost:           2.18 $
# Heat Cost:           0.00 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.46 $
#
#
# --- Day 155 ---
# Raw-obs: biomass=46655.1 g, count=100, temp=28.81°C, DO=0.99 mg/L, UIA=0.520 mg/L
# Action: feed_rate=0.418 → feed_amt=1947.95 g, temp_set=25.386, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.3017914952848528 $
# Feed Cost:           2.20 $
# Heat Cost:           0.00 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.46 $
#
#
# --- Day 156 ---
# Raw-obs: biomass=46999.5 g, count=100, temp=28.88°C, DO=0.99 mg/L, UIA=0.524 mg/L
# Action: feed_rate=0.412 → feed_amt=1938.12 g, temp_set=25.294, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.2823351525319067 $
# Feed Cost:           2.19 $
# Heat Cost:           0.00 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.44 $
#
#
# --- Day 157 ---
# Raw-obs: biomass=47338.7 g, count=100, temp=28.92°C, DO=0.99 mg/L, UIA=0.524 mg/L
# Action: feed_rate=0.411 → feed_amt=1945.91 g, temp_set=25.266, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.285856760569047 $
# Feed Cost:           2.20 $
# Heat Cost:           0.00 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.44 $
#
#
# --- Day 158 ---
# Raw-obs: biomass=47678.9 g, count=100, temp=28.98°C, DO=0.99 mg/L, UIA=0.527 mg/L
# Action: feed_rate=0.407 → feed_amt=1940.21 g, temp_set=25.197, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.2634025733315266 $
# Feed Cost:           2.19 $
# Heat Cost:           0.00 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.40 $
#
#
# --- Day 159 ---
# Raw-obs: biomass=48013.1 g, count=100, temp=29.00°C, DO=0.99 mg/L, UIA=0.527 mg/L
# Action: feed_rate=0.406 → feed_amt=1951.30 g, temp_set=25.187, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.2709032762562333 $
# Feed Cost:           2.20 $
# Heat Cost:           0.00 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.40 $
#
#
# --- Day 160 ---
# Raw-obs: biomass=48349.3 g, count=100, temp=29.06°C, DO=0.99 mg/L, UIA=0.531 mg/L
# Action: feed_rate=0.402 → feed_amt=1941.59 g, temp_set=25.111, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.2398264710984217 $
# Feed Cost:           2.19 $
# Heat Cost:           0.00 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.35 $
#
#
# --- Day 161 ---
# Raw-obs: biomass=48677.3 g, count=100, temp=29.07°C, DO=0.99 mg/L, UIA=0.530 mg/L
# Action: feed_rate=0.402 → feed_amt=1958.79 g, temp_set=25.122, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.2474821320795182 $
# Feed Cost:           2.21 $
# Heat Cost:           0.00 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.35 $
#
#
# --- Day 162 ---
# Raw-obs: biomass=49007.4 g, count=100, temp=29.10°C, DO=0.99 mg/L, UIA=0.533 mg/L
# Action: feed_rate=0.397 → feed_amt=1943.96 g, temp_set=25.057, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.2176813747298136 $
# Feed Cost:           2.19 $
# Heat Cost:           0.00 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.30 $
#
#
# --- Day 163 ---
# Raw-obs: biomass=49329.5 g, count=100, temp=29.13°C, DO=0.99 mg/L, UIA=0.533 mg/L
# Action: feed_rate=0.396 → feed_amt=1955.89 g, temp_set=25.058, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.207476990357031 $
# Feed Cost:           2.20 $
# Heat Cost:           0.00 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.27 $
#
#
# --- Day 164 ---
# Raw-obs: biomass=49648.9 g, count=100, temp=29.10°C, DO=0.99 mg/L, UIA=0.533 mg/L
# Action: feed_rate=0.397 → feed_amt=1969.27 g, temp_set=25.056, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.2145515548079833 $
# Feed Cost:           2.22 $
# Heat Cost:           0.00 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.27 $
#
#
# --- Day 165 ---
# Raw-obs: biomass=49970.2 g, count=100, temp=29.15°C, DO=0.99 mg/L, UIA=0.537 mg/L
# Action: feed_rate=0.388 → feed_amt=1939.55 g, temp_set=24.976, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.1765944369625456 $
# Feed Cost:           2.19 $
# Heat Cost:           0.00 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.23 $
#
#
# --- Day 166 ---
# Raw-obs: biomass=50281.5 g, count=100, temp=29.22°C, DO=0.99 mg/L, UIA=0.535 mg/L
# Action: feed_rate=0.387 → feed_amt=1946.57 g, temp_set=24.984, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.1842089717368436 $
# Feed Cost:           2.19 $
# Heat Cost:           0.00 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.23 $
#
#
# --- Day 167 ---
# Raw-obs: biomass=50594.8 g, count=100, temp=29.30°C, DO=0.99 mg/L, UIA=0.538 mg/L
# Action: feed_rate=0.376 → feed_amt=1904.86 g, temp_set=24.912, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.1294091757258846 $
# Feed Cost:           2.15 $
# Heat Cost:           0.00 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.17 $
#
#
# --- Day 168 ---
# Raw-obs: biomass=50893.6 g, count=100, temp=29.34°C, DO=0.99 mg/L, UIA=0.534 mg/L
# Action: feed_rate=0.382 → feed_amt=1943.48 g, temp_set=24.967, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.1707108115606282 $
# Feed Cost:           2.19 $
# Heat Cost:           0.00 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.21 $
#
#
# --- Day 169 ---
# Raw-obs: biomass=51203.3 g, count=100, temp=29.42°C, DO=0.99 mg/L, UIA=0.541 mg/L
# Action: feed_rate=0.364 → feed_amt=1862.75 g, temp_set=24.837, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.0613118911999644 $
# Feed Cost:           2.10 $
# Heat Cost:           0.00 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.07 $
#
#
# --- Day 170 ---
# Raw-obs: biomass=51484.1 g, count=100, temp=29.40°C, DO=0.99 mg/L, UIA=0.530 mg/L
# Action: feed_rate=0.386 → feed_amt=1987.63 g, temp_set=25.019, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.1877154667650518 $
# Feed Cost:           2.24 $
# Heat Cost:           0.00 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.20 $
#
#
# --- Day 171 ---
# Raw-obs: biomass=51798.3 g, count=100, temp=29.42°C, DO=0.99 mg/L, UIA=0.547 mg/L
# Action: feed_rate=0.354 → feed_amt=1834.71 g, temp_set=24.765, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.0027167285692757 $
# Feed Cost:           2.07 $
# Heat Cost:           0.00 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        -0.01 $
#
#
# --- Day 172 ---
# Raw-obs: biomass=52063.5 g, count=100, temp=29.43°C, DO=0.99 mg/L, UIA=0.527 mg/L
# Action: feed_rate=0.388 → feed_amt=2019.60 g, temp_set=25.045, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.2140824642584251 $
# Feed Cost:           2.28 $
# Heat Cost:           0.00 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.22 $
#
#
# --- Day 173 ---
# Raw-obs: biomass=52384.7 g, count=100, temp=29.57°C, DO=0.99 mg/L, UIA=0.556 mg/L
# Action: feed_rate=0.328 → feed_amt=1719.69 g, temp_set=24.641, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     0.878287060807207 $
# Feed Cost:           1.93 $
# Heat Cost:           0.00 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        -0.15 $
#
#
# --- Day 174 ---
# Raw-obs: biomass=52617.1 g, count=100, temp=29.67°C, DO=0.99 mg/L, UIA=0.517 mg/L
# Action: feed_rate=0.391 → feed_amt=2059.80 g, temp_set=25.141, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.256858030843573 $
# Feed Cost:           2.32 $
# Heat Cost:           0.00 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.26 $
#
#
# --- Day 175 ---
# Raw-obs: biomass=52949.6 g, count=100, temp=29.73°C, DO=0.99 mg/L, UIA=0.565 mg/L
# Action: feed_rate=0.291 → feed_amt=1539.75 g, temp_set=24.678, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     0.6873966831794365 $
# Feed Cost:           1.73 $
# Heat Cost:           0.00 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        -0.34 $
#
#
# --- Day 176 ---
# Raw-obs: biomass=53131.4 g, count=100, temp=29.85°C, DO=0.99 mg/L, UIA=0.493 mg/L
# Action: feed_rate=0.427 → feed_amt=2268.49 g, temp_set=25.587, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.4745509665575092 $
# Feed Cost:           2.56 $
# Heat Cost:           0.00 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.49 $
#
#
# --- Day 177 ---
# Raw-obs: biomass=53521.5 g, count=100, temp=29.87°C, DO=0.99 mg/L, UIA=0.595 mg/L
# Action: feed_rate=0.221 → feed_amt=1183.59 g, temp_set=24.708, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     0.3620639312858502 $
# Feed Cost:           1.33 $
# Heat Cost:           0.00 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        -0.63 $
#
#
# --- Day 178 ---
# Raw-obs: biomass=53617.3 g, count=100, temp=29.89°C, DO=0.99 mg/L, UIA=0.431 mg/L
# Action: feed_rate=0.499 → feed_amt=2674.11 g, temp_set=27.383, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     1.8663474938894098 $
# Feed Cost:           3.02 $
# Heat Cost:           0.00 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.85 $
#
#
# --- Day 179 ---
# Raw-obs: biomass=54111.0 g, count=100, temp=29.92°C, DO=0.99 mg/L, UIA=0.638 mg/L
# Action: feed_rate=0.169 → feed_amt=913.44 g, temp_set=24.763, aeration_rate=0.98mg/L
#
# Reward Breakdown:
# Fish Value Gain:     0.18036074366598553 $
# Feed Cost:           1.02 $
# Heat Cost:           0.00 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        -0.72 $
#
#
# --- Day 180 ---
# Raw-obs: biomass=54158.8 g, count=100, temp=29.94°C, DO=0.98 mg/L, UIA=0.382 mg/L
# Action: feed_rate=0.551 → feed_amt=2981.80 g, temp_set=28.258, aeration_rate=0.99mg/L
#
# Reward Breakdown:
# Fish Value Gain:     2.0824471888415195 $
# Feed Cost:           3.37 $
# Heat Cost:           0.00 $
# Oxygenation Cost:    0.21 $
# → Net Reward:        0.97 $
#
# Total Reward: 57.397972989473416
